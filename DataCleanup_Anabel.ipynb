# %%
# This script will start the cleanup of the Movie data

import seaborn as sns
import math
import pandas as pd
import ast
import numpy as np
import matplotlib.pyplot as plt
data_folder = './Data/'

# %%
movies_metadata = pd.read_csv(data_folder+'movie.metadata.tsv', header=None, sep='\t', names=['wikipedia_ID','freebase_ID','name','release_date', 'box_office_revenue', 'runtime', 'languages', 'countries', 'genre'], parse_dates=False)
movies_metadata.head(5)
# Out:
#    wikipedia_ID freebase_ID  \
# 0        975900   /m/03vyhn
# 1       3196793   /m/08yl5d
# 2      28463795  /m/0crgdbh
# 3       9363483  /m/0285_cd
# 4        261236   /m/01mrr1
#
#                                                 name release_date  \
# 0                                     Ghosts of Mars   2001-08-24
# 1  Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                        Brun bitter         1988
# 3                                   White Of The Eye         1987
# 4                                  A Woman in Flames         1983
#
#    box_office_revenue  runtime                           languages  \
# 0          14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1                 NaN     95.0  {"/m/02h40lc": "English Language"}
# 2                 NaN     83.0  {"/m/05f_3": "Norwegian Language"}
# 3                 NaN    110.0  {"/m/02h40lc": "English Language"}
# 4                 NaN    106.0   {"/m/04306rv": "German Language"}
#
#                                    countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2                     {"/m/05b4w": "Norway"}
# 3             {"/m/07ssc": "United Kingdom"}
# 4                    {"/m/0345h": "Germany"}
#
#                                                genre
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                            {"/m/07s9rl0": "Drama"}

# %%
character_metadata = pd.read_csv(data_folder+'character.metadata.tsv', header=None, sep='\t', names=['wikipedia_ID','freebase_ID','release_date', 'character_name', 'actor_birthday', 'actor_gender', 'actor_height', 'actor_ethnicity', 'actor_name' , 'actor_age','freebase_character_actor_mapID', 'freebase_character_ID', 'freebase_actor_ID' ], parse_dates=False)
character_metadata.head(5)
# Out:
#    wikipedia_ID freebase_ID release_date              character_name  \
# 0        975900   /m/03vyhn   2001-08-24                    Akooshay
# 1        975900   /m/03vyhn   2001-08-24  Lieutenant Melanie Ballard
# 2        975900   /m/03vyhn   2001-08-24         Desolation Williams
# 3        975900   /m/03vyhn   2001-08-24          Sgt Jericho Butler
# 4        975900   /m/03vyhn   2001-08-24             Bashira Kincaid
#
#   actor_birthday actor_gender  actor_height actor_ethnicity  \
# 0     1958-08-26            F         1.620             NaN
# 1     1974-08-15            F         1.780      /m/044038p
# 2     1969-06-15            M         1.727         /m/0x67
# 3     1967-09-12            M         1.750             NaN
# 4     1977-09-25            F         1.650             NaN
#
#            actor_name  actor_age freebase_character_actor_mapID  \
# 0      Wanda De Jesus       42.0                     /m/0bgchxw
# 1  Natasha Henstridge       27.0                      /m/0jys3m
# 2            Ice Cube       32.0                      /m/0jys3g
# 3       Jason Statham       33.0                     /m/02vchl6
# 4         Clea DuVall       23.0                     /m/02vbb3r
#
#   freebase_character_ID freebase_actor_ID
# 0            /m/0bgcj3x        /m/03wcfv7
# 1            /m/0bgchn4         /m/0346l4
# 2            /m/0bgchn_        /m/01vw26l
# 3            /m/0bgchnq         /m/034hyc
# 4            /m/0bgchp9         /m/01y9xg

# %%
plot_summaries = pd.read_csv(data_folder+'plot_summaries.txt',sep='\t', header=None, names=['wikipedia_ID', 'plot_summary'] )
plot_summaries.head()
# Out:
#    wikipedia_ID                                       plot_summary
# 0      23890098  Shlykov, a hard-working taxi driver and Lyosha...
# 1      31186339  The nation of Panem consists of a wealthy Capi...
# 2      20663735  Poovalli Induchoodan  is sentenced for six yea...
# 3       2231378  The Lemon Drop Kid , a New York City swindler,...
# 4        595909  Seventh-day Adventist Church pastor Michael Ch...

# %% [markdown]
# **How many movies do we have?**

# %%
number_of_data= movies_metadata.count()
number_of_data
# Out:
# wikipedia_ID          81741
# freebase_ID           81741
# name                  81741
# release_date          74839
# box_office_revenue     8401
# runtime               61291
# languages             81741
# countries             81741
# genre                 81741
# dtype: int64

# %% [markdown]
# **Where is data mostly missing ?**

# %%
proportion_of_each_data = number_of_data/number_of_data['wikipedia_ID']*100
proportion_of_each_data
# Out:
# wikipedia_ID          100.000000
# freebase_ID           100.000000
# name                  100.000000
# release_date           91.556257
# box_office_revenue     10.277584
# runtime                74.981955
# languages             100.000000
# countries             100.000000
# genre                 100.000000
# dtype: float64

# %% [markdown]
# We see that the box office column is a column with a lot of missing data, it is only present for 10% of movies.

# %% [markdown]
# Given we will perform our analysis on American movies we will only keep the data for movies from the US

# %%
us_movies_metadata = movies_metadata[movies_metadata['countries'].str.contains('United States of America', case=False)].copy()
us_movies_metadata
# Out:
#        wikipedia_ID freebase_ID  \
# 0            975900   /m/03vyhn
# 1           3196793   /m/08yl5d
# 5          13696889  /m/03cfc81
# 7          10408933  /m/02qc0j7
# 10           175026   /m/017n1p
# ...             ...         ...
# 81725       1918494   /m/0660qx
# 81726        664006   /m/030xw6
# 81727      24209227  /m/07k5mlk
# 81736      35228177  /m/0j7hxnt
# 81738       9971909  /m/02pygw1
#
#                                                     name release_date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 5                                          The Gangsters   1913-05-29
# 7                               Alexander's Ragtime Band   1938-08-16
# 10                                         Sarah and Son         1930
# ...                                                  ...          ...
# 81725                                     State and Main   2000-08-26
# 81726                                      Guilty as Sin   1993-06-04
# 81727                   The Time, the Place and the Girl         1946
# 81736                           Mermaids: The Body Found   2011-03-19
# 81738                                  Another Nice Mess   1972-09-22
#
#        box_office_revenue  runtime  \
# 0              14010832.0     98.0
# 1                     NaN     95.0
# 5                     NaN     35.0
# 7               3600000.0    106.0
# 10                    NaN     86.0
# ...                   ...      ...
# 81725           6944471.0    106.0
# 81726          22886222.0    107.0
# 81727                 NaN    105.0
# 81736                 NaN    120.0
# 81738                 NaN     66.0
#
#                                                languages  \
# 0                     {"/m/02h40lc": "English Language"}
# 1                     {"/m/02h40lc": "English Language"}
# 5      {"/m/06ppq": "Silent film", "/m/02h40lc": "Eng...
# 7                     {"/m/02h40lc": "English Language"}
# 10                    {"/m/02h40lc": "English Language"}
# ...                                                  ...
# 81725  {"/m/02bjrlw": "Italian Language", "/m/02h40lc...
# 81726                                                 {}
# 81727                 {"/m/02h40lc": "English Language"}
# 81736                 {"/m/02h40lc": "English Language"}
# 81738                 {"/m/02h40lc": "English Language"}
#
#                                                countries  \
# 0              {"/m/09c7w0": "United States of America"}
# 1              {"/m/09c7w0": "United States of America"}
# 5              {"/m/09c7w0": "United States of America"}
# 7              {"/m/09c7w0": "United States of America"}
# 10             {"/m/09c7w0": "United States of America"}
# ...                                                  ...
# 81725  {"/m/0f8l9c": "France", "/m/09c7w0": "United S...
# 81726          {"/m/09c7w0": "United States of America"}
# 81727          {"/m/09c7w0": "United States of America"}
# 81736          {"/m/09c7w0": "United States of America"}
# 81738          {"/m/09c7w0": "United States of America"}
#
#                                                    genre
# 0      {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1      {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 5      {"/m/02hmvc": "Short Film", "/m/06ppq": "Silen...
# 7      {"/m/04t36": "Musical", "/m/01z4y": "Comedy", ...
# 10     {"/m/07s9rl0": "Drama", "/m/01g6gs": "Black-an...
# ...                                                  ...
# 81725  {"/m/0gf28": "Parody", "/m/09n5t_": "Americana...
# 81726  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 81727  {"/m/05p553": "Comedy film", "/m/02l7c8": "Rom...
# 81736                            {"/m/07s9rl0": "Drama"}
# 81738       {"/m/06nbt": "Satire", "/m/01z4y": "Comedy"}
#
# [34408 rows x 9 columns]

# %%
us_movies_metadata['languages'] = us_movies_metadata['languages'].apply(lambda x: list(ast.literal_eval(x).values()))
us_movies_metadata
# Out:
#        wikipedia_ID freebase_ID  \
# 0            975900   /m/03vyhn
# 1           3196793   /m/08yl5d
# 5          13696889  /m/03cfc81
# 7          10408933  /m/02qc0j7
# 10           175026   /m/017n1p
# ...             ...         ...
# 81725       1918494   /m/0660qx
# 81726        664006   /m/030xw6
# 81727      24209227  /m/07k5mlk
# 81736      35228177  /m/0j7hxnt
# 81738       9971909  /m/02pygw1
#
#                                                     name release_date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 5                                          The Gangsters   1913-05-29
# 7                               Alexander's Ragtime Band   1938-08-16
# 10                                         Sarah and Son         1930
# ...                                                  ...          ...
# 81725                                     State and Main   2000-08-26
# 81726                                      Guilty as Sin   1993-06-04
# 81727                   The Time, the Place and the Girl         1946
# 81736                           Mermaids: The Body Found   2011-03-19
# 81738                                  Another Nice Mess   1972-09-22
#
#        box_office_revenue  runtime                             languages  \
# 0              14010832.0     98.0                    [English Language]
# 1                     NaN     95.0                    [English Language]
# 5                     NaN     35.0       [Silent film, English Language]
# 7               3600000.0    106.0                    [English Language]
# 10                    NaN     86.0                    [English Language]
# ...                   ...      ...                                   ...
# 81725           6944471.0    106.0  [Italian Language, English Language]
# 81726          22886222.0    107.0                                    []
# 81727                 NaN    105.0                    [English Language]
# 81736                 NaN    120.0                    [English Language]
# 81738                 NaN     66.0                    [English Language]
#
#                                                countries  \
# 0              {"/m/09c7w0": "United States of America"}
# 1              {"/m/09c7w0": "United States of America"}
# 5              {"/m/09c7w0": "United States of America"}
# 7              {"/m/09c7w0": "United States of America"}
# 10             {"/m/09c7w0": "United States of America"}
# ...                                                  ...
# 81725  {"/m/0f8l9c": "France", "/m/09c7w0": "United S...
# 81726          {"/m/09c7w0": "United States of America"}
# 81727          {"/m/09c7w0": "United States of America"}
# 81736          {"/m/09c7w0": "United States of America"}
# 81738          {"/m/09c7w0": "United States of America"}
#
#                                                    genre
# 0      {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1      {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 5      {"/m/02hmvc": "Short Film", "/m/06ppq": "Silen...
# 7      {"/m/04t36": "Musical", "/m/01z4y": "Comedy", ...
# 10     {"/m/07s9rl0": "Drama", "/m/01g6gs": "Black-an...
# ...                                                  ...
# 81725  {"/m/0gf28": "Parody", "/m/09n5t_": "Americana...
# 81726  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 81727  {"/m/05p553": "Comedy film", "/m/02l7c8": "Rom...
# 81736                            {"/m/07s9rl0": "Drama"}
# 81738       {"/m/06nbt": "Satire", "/m/01z4y": "Comedy"}
#
# [34408 rows x 9 columns]

# %% [markdown]
# How many movies did we keep?

# %%
print(us_movies_metadata.count())
# Out:
# wikipedia_ID          34408
# freebase_ID           34408
# name                  34408
# release_date          33197
# box_office_revenue     6936
# runtime               29509
# languages             34408
# countries             34408
# genre                 34408
# dtype: int64

# %%
print('Total Number of movies', number_of_data.wikipedia_ID)
print('Number of non-US movies', number_of_data.wikipedia_ID - us_movies_metadata.wikipedia_ID.count())
print('Meaning we will be working with',us_movies_metadata.wikipedia_ID.count(), 'movies for our analysis')
# Out:
# Total Number of movies 81741
# Number of non-US movies 47333
# Meaning we will be working with 34408 movies for our analysis

# %%
#Let's remove the dictionaries from the countries and the genre of our data

us_movies_metadata['countries'] = us_movies_metadata['countries'].apply(lambda x: list(ast.literal_eval(x).values()))
us_movies_metadata['genre'] = us_movies_metadata['genre'].apply(lambda x: list(ast.literal_eval(x).values()))

us_movies_metadata
# Out:
#        wikipedia_ID freebase_ID  \
# 0            975900   /m/03vyhn
# 1           3196793   /m/08yl5d
# 5          13696889  /m/03cfc81
# 7          10408933  /m/02qc0j7
# 10           175026   /m/017n1p
# ...             ...         ...
# 81725       1918494   /m/0660qx
# 81726        664006   /m/030xw6
# 81727      24209227  /m/07k5mlk
# 81736      35228177  /m/0j7hxnt
# 81738       9971909  /m/02pygw1
#
#                                                     name release_date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 5                                          The Gangsters   1913-05-29
# 7                               Alexander's Ragtime Band   1938-08-16
# 10                                         Sarah and Son         1930
# ...                                                  ...          ...
# 81725                                     State and Main   2000-08-26
# 81726                                      Guilty as Sin   1993-06-04
# 81727                   The Time, the Place and the Girl         1946
# 81736                           Mermaids: The Body Found   2011-03-19
# 81738                                  Another Nice Mess   1972-09-22
#
#        box_office_revenue  runtime                             languages  \
# 0              14010832.0     98.0                    [English Language]
# 1                     NaN     95.0                    [English Language]
# 5                     NaN     35.0       [Silent film, English Language]
# 7               3600000.0    106.0                    [English Language]
# 10                    NaN     86.0                    [English Language]
# ...                   ...      ...                                   ...
# 81725           6944471.0    106.0  [Italian Language, English Language]
# 81726          22886222.0    107.0                                    []
# 81727                 NaN    105.0                    [English Language]
# 81736                 NaN    120.0                    [English Language]
# 81738                 NaN     66.0                    [English Language]
#
#                                 countries  \
# 0              [United States of America]
# 1              [United States of America]
# 5              [United States of America]
# 7              [United States of America]
# 10             [United States of America]
# ...                                   ...
# 81725  [France, United States of America]
# 81726          [United States of America]
# 81727          [United States of America]
# 81736          [United States of America]
# 81738          [United States of America]
#
#                                                    genre
# 0      [Thriller, Science Fiction, Horror, Adventure,...
# 1       [Mystery, Biographical film, Drama, Crime Drama]
# 5      [Short Film, Silent film, Indie, Black-and-whi...
# 7                     [Musical, Comedy, Black-and-white]
# 10                              [Drama, Black-and-white]
# ...                                                  ...
# 81725                        [Parody, Americana, Comedy]
# 81726  [Thriller, Erotic thriller, Psychological thri...
# 81727               [Comedy film, Romance Film, Musical]
# 81736                                            [Drama]
# 81738                                   [Satire, Comedy]
#
# [34408 rows x 9 columns]

# %% [markdown]
# Let's see what languages we still have in our data

# %%
us_movies_metadata["languages"].explode().unique()
# Out:
# array(['English Language', 'Silent film', nan, 'Spanish Language',
#        'Greek Language', 'Swahili Language', 'French Language',
#        'Standard Mandarin', 'Standard Cantonese', 'Italian Language',
#        'Japanese Language', 'American English', 'German Language',
#        'Arabic Language', 'Czech Language', 'Slovak Language',
#        'Thai Language', 'Portuguese Language', 'Polish Language',
#        'Tibetan languages', 'Mandarin Chinese', 'Cantonese',
#        'Standard Tibetan', 'Chinese language', 'Swedish Language',
#        'Hungarian language', 'Russian Language', 'Dutch Language',
#        'Persian Language', 'Irish', 'American Sign Language',
#        'Tagalog language', 'Filipino language', 'Xhosa Language',
#        'Afrikaans Language', 'Urdu Language', 'Hebrew Language',
#        'Tamil Language', 'Latin Language', 'Turkish Language',
#        'Hindi Language', 'Serbo-Croatian', 'Croatian language',
#        'Serbian language', 'Kannada Language', 'Punjabi language',
#        'Bengali Language', 'Yiddish Language', 'Navajo Language',
#        'Algonquin Language', 'Ukrainian Language', 'Aramaic language',
#        'Vietnamese Language', 'Esperanto Language', 'Danish Language',
#        'Romanian Language', 'Maya, Yucatán Language', 'Quechua',
#        'Korean Language', 'Bulgarian Language', 'Welsh Language',
#        'Finnish Language', 'Old English language', 'Icelandic Language',
#        'Apache, Western Language', 'Kurdish language',
#        'Macedonian Language', 'Estonian Language', 'Amharic Language',
#        'Lithuanian language', 'Armenian Language', 'Gaelic',
#        'Albanian language', 'Malay Language', 'Sioux language',
#        'Pawnee Language', 'Corsican Language', 'Hopi Language',
#        'Pashto language', 'Dari', 'Aboriginal Malay languages',
#        'Norwegian Language', 'Kinyarwanda language', 'Mende Language',
#        'Assyrian Neo-Aramaic Language', 'Gujarati Language',
#        'Egyptian, Ancient', 'Sanskrit Language', 'Zulu Language',
#        'Ancient Greek', 'Scottish Gaelic language', 'Tok Pisin Language',
#        'Crow Language', 'Bosnian language', 'Cheyenne Language',
#        'Somali Language', 'Hawaiian language', 'Galician Language',
#        'Sinhala Language', 'French Sign Language', 'Sumerian',
#        'Georgian Language', 'France', 'Wolof Language',
#        'Swiss German Language', 'Australian English', 'Telugu language',
#        'Malayalam Language', 'Sicilian Language', 'Cree language',
#        'Māori language', 'Korean Sign Language', 'Luxembourgish language',
#        'Krio Language', 'Mongolian language', 'Indian English',
#        'Khmer language', 'Cebuano language', 'Plautdietsch Language',
#        'Nepali Language', 'German', 'Klingon language', 'Akan Language',
#        'Shanghainese', 'Indonesian Language', 'Hmong language', 'Deutsch',
#        'Italian', 'Sotho language', 'Chewa language', 'Mohawk Language',
#        'Napoletano-Calabrese Language', 'Burmese Language',
#        'Brazilian Portuguese', 'Assyrian language', 'Romani language',
#        'Inuktitut', 'Min Nan', 'Taiwanese', 'Papiamento language',
#        'Tzotzil language', 'Nahuatl languages', 'Kuna language',
#        'Hausa Language'], dtype=object)

# %% [markdown]
# Of interest for us are: English Language, Silent Film, American English, Old English Language (for example Indian English is not very relevant for our analysis, as well as native american languages like Navajo or Hawaiian language). So let us remove any movie that doesn't have English Language, Silent Film, American English, Old English Language, or American Sign Language as one of their language

# %%
us_english_movies_metadata = us_movies_metadata[movies_metadata['languages'].str.contains('English Language' or 'Silent Film' or 'American English' or 'Old English Language' or 'American Sign Language', case=False)].copy()
us_english_movies_metadata
# Out:
# /var/folders/59/tl5brg352p5flp89qk_6vy_00000gn/T/ipykernel_1191/4269780988.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   us_english_movies_metadata = us_movies_metadata[movies_metadata['languages'].str.contains('English Language' or 'Silent Film' or 'American English' or 'Old English Language' or 'American Sign Language', case=False)].copy()
#        wikipedia_ID freebase_ID  \
# 0            975900   /m/03vyhn
# 1           3196793   /m/08yl5d
# 5          13696889  /m/03cfc81
# 7          10408933  /m/02qc0j7
# 10           175026   /m/017n1p
# ...             ...         ...
# 81721      34474142  /m/0cpy07r
# 81725       1918494   /m/0660qx
# 81727      24209227  /m/07k5mlk
# 81736      35228177  /m/0j7hxnt
# 81738       9971909  /m/02pygw1
#
#                                                     name release_date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 5                                          The Gangsters   1913-05-29
# 7                               Alexander's Ragtime Band   1938-08-16
# 10                                         Sarah and Son         1930
# ...                                                  ...          ...
# 81721                                      Frontier Fury   1943-06-24
# 81725                                     State and Main   2000-08-26
# 81727                   The Time, the Place and the Girl         1946
# 81736                           Mermaids: The Body Found   2011-03-19
# 81738                                  Another Nice Mess   1972-09-22
#
#        box_office_revenue  runtime                             languages  \
# 0              14010832.0     98.0                    [English Language]
# 1                     NaN     95.0                    [English Language]
# 5                     NaN     35.0       [Silent film, English Language]
# 7               3600000.0    106.0                    [English Language]
# 10                    NaN     86.0                    [English Language]
# ...                   ...      ...                                   ...
# 81721                 NaN     55.0                    [English Language]
# 81725           6944471.0    106.0  [Italian Language, English Language]
# 81727                 NaN    105.0                    [English Language]
# 81736                 NaN    120.0                    [English Language]
# 81738                 NaN     66.0                    [English Language]
#
#                                 countries  \
# 0              [United States of America]
# 1              [United States of America]
# 5              [United States of America]
# 7              [United States of America]
# 10             [United States of America]
# ...                                   ...
# 81721          [United States of America]
# 81725  [France, United States of America]
# 81727          [United States of America]
# 81736          [United States of America]
# 81738          [United States of America]
#
#                                                    genre
# 0      [Thriller, Science Fiction, Horror, Adventure,...
# 1       [Mystery, Biographical film, Drama, Crime Drama]
# 5      [Short Film, Silent film, Indie, Black-and-whi...
# 7                     [Musical, Comedy, Black-and-white]
# 10                              [Drama, Black-and-white]
# ...                                                  ...
# 81721                                          [Western]
# 81725                        [Parody, Americana, Comedy]
# 81727               [Comedy film, Romance Film, Musical]
# 81736                                            [Drama]
# 81738                                   [Satire, Comedy]
#
# [30528 rows x 9 columns]

# %% [markdown]
# Did we remove any movies by doing that?

# %%
print('We had',us_movies_metadata.wikipedia_ID.count(), 'movies in our U.S data frame')
print('We now have', us_english_movies_metadata.wikipedia_ID.count(), 'in our English US data frame')
print('So there are',us_movies_metadata.wikipedia_ID.count()-us_english_movies_metadata.wikipedia_ID.count(), 'movies that were from the US but not in any of the languages we decided to consider' )
# Out:
# We had 34408 movies in our U.S data frame
# We now have 30528 in our English US data frame
# So there are 3880 movies that were from the US but not in any of the languages we decided to consider

# %% [markdown]
# **Small alternative:** keep movies that have NaN as languages to complement it potentially later:

# %%
# of course this can be modified if we decide to keep more languages
languages_to_keep = ['English Language', 'Silent Film','American English','Old English Language', 'American Sign Language']

us_english_movie_with_nan_metadata = us_movies_metadata[us_movies_metadata['languages'].apply(lambda x: any(lang in x for lang in languages_to_keep) or len(x) == 0)]
us_english_movie_with_nan_metadata
# Out:
#        wikipedia_ID freebase_ID  \
# 0            975900   /m/03vyhn
# 1           3196793   /m/08yl5d
# 5          13696889  /m/03cfc81
# 7          10408933  /m/02qc0j7
# 10           175026   /m/017n1p
# ...             ...         ...
# 81725       1918494   /m/0660qx
# 81726        664006   /m/030xw6
# 81727      24209227  /m/07k5mlk
# 81736      35228177  /m/0j7hxnt
# 81738       9971909  /m/02pygw1
#
#                                                     name release_date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 5                                          The Gangsters   1913-05-29
# 7                               Alexander's Ragtime Band   1938-08-16
# 10                                         Sarah and Son         1930
# ...                                                  ...          ...
# 81725                                     State and Main   2000-08-26
# 81726                                      Guilty as Sin   1993-06-04
# 81727                   The Time, the Place and the Girl         1946
# 81736                           Mermaids: The Body Found   2011-03-19
# 81738                                  Another Nice Mess   1972-09-22
#
#        box_office_revenue  runtime                             languages  \
# 0              14010832.0     98.0                    [English Language]
# 1                     NaN     95.0                    [English Language]
# 5                     NaN     35.0       [Silent film, English Language]
# 7               3600000.0    106.0                    [English Language]
# 10                    NaN     86.0                    [English Language]
# ...                   ...      ...                                   ...
# 81725           6944471.0    106.0  [Italian Language, English Language]
# 81726          22886222.0    107.0                                    []
# 81727                 NaN    105.0                    [English Language]
# 81736                 NaN    120.0                    [English Language]
# 81738                 NaN     66.0                    [English Language]
#
#                                 countries  \
# 0              [United States of America]
# 1              [United States of America]
# 5              [United States of America]
# 7              [United States of America]
# 10             [United States of America]
# ...                                   ...
# 81725  [France, United States of America]
# 81726          [United States of America]
# 81727          [United States of America]
# 81736          [United States of America]
# 81738          [United States of America]
#
#                                                    genre
# 0      [Thriller, Science Fiction, Horror, Adventure,...
# 1       [Mystery, Biographical film, Drama, Crime Drama]
# 5      [Short Film, Silent film, Indie, Black-and-whi...
# 7                     [Musical, Comedy, Black-and-white]
# 10                              [Drama, Black-and-white]
# ...                                                  ...
# 81725                        [Parody, Americana, Comedy]
# 81726  [Thriller, Erotic thriller, Psychological thri...
# 81727               [Comedy film, Romance Film, Musical]
# 81736                                            [Drama]
# 81738                                   [Satire, Comedy]
#
# [34077 rows x 9 columns]

# %%
print('While we kept', us_english_movies_metadata.wikipedia_ID.count(), 'movies in our dataframe by removing movies that had no language provided, we keep',us_english_movie_with_nan_metadata.wikipedia_ID.count(), 'by keeping those movies. Thereby, only removing', us_movies_metadata.wikipedia_ID.count() - us_english_movie_with_nan_metadata.wikipedia_ID.count(), 'movies.' )
# Out:
# While we kept 30528 movies in our dataframe by removing movies that had no language provided, we keep 34077 by keeping those movies. Thereby, only removing 331 movies.

# %% [markdown]
# **Now let us have a look at the genres we have in our dataset**

# %%
us_movies_metadata["genre"].explode().unique()
# Out:
# array(['Thriller', 'Science Fiction', 'Horror', 'Adventure',
#        'Supernatural', 'Action', 'Space western', 'Mystery',
#        'Biographical film', 'Drama', 'Crime Drama', 'Short Film',
#        'Silent film', 'Indie', 'Black-and-white', 'Comedy', 'Musical',
#        'Romantic comedy', 'Ensemble Film', 'Comedy-drama',
#        'Romantic drama', 'Romance Film', 'Animation', 'Fantasy',
#        'Family Film', "Children's/Family", "Children's Fantasy",
#        'Future noir', 'Erotic thriller', 'Film adaptation',
#        'Crime Fiction', 'Coming of age', 'Psychological thriller',
#        'Suspense', 'Crime Thriller', 'Black comedy', 'Marriage Drama',
#        'Western', 'Parody', 'Mockumentary', 'Fan film', 'War film',
#        'Epic', 'Biopic [feature]', 'Historical Epic', 'Sports',
#        'Family Drama', 'Action/Adventure', 'Costume drama',
#        'Historical fiction', 'Culture & Society', 'Biography',
#        'Documentary', 'Christmas movie', 'Television movie',
#        'Action Comedy', 'Cult', 'Blaxploitation', 'Martial Arts Film',
#        'Epic Western', 'Softcore Porn', 'Sexploitation', 'B-movie',
#        'Zombie Film', 'Action Thrillers', 'Comedy film', 'Slasher',
#        'Film noir', 'Social issues', 'Satire', 'Legal drama',
#        'Courtroom Drama', 'New Hollywood', 'Musical Drama',
#        'Gangster Film', 'Crime Comedy', 'Fantasy Comedy', 'Monster movie',
#        'Natural horror films', 'Creature Film', 'Gender Issues', 'LGBT',
#        'Political thriller', 'Political drama', 'Melodrama', 'Americana',
#        'Detective fiction', 'Detective', 'Music', 'Concert film',
#        'History', 'Sci-Fi Horror', 'Horror Comedy', 'Childhood Drama',
#        'Docudrama', 'Teen', 'Gothic Film', 'Disaster', 'Musical comedy',
#        'Family-Oriented Adventure', 'Escape Film', 'Prison',
#        'Superhero movie', 'Spy', 'Combat Films', 'Wuxia',
#        'Fantasy Adventure', 'Period piece', 'Chinese Movies',
#        'Political cinema', 'Slapstick', 'Erotic Drama', 'Erotica',
#        'World cinema', 'Tragedy', 'Buddy film', 'Time travel',
#        'Pornographic movie', 'Sword and sorcery', 'Gross-out film',
#        'Gross out', 'Historical drama', 'Doomsday film', 'Plague',
#        'Japanese Movies', 'Propaganda film', 'Screwball comedy',
#        'Comedy Western', 'Rockumentary', 'Gay', 'Gay Interest',
#        'Gay Themed', 'Film à clef', 'Feminist Film', nan, 'Pre-Code',
#        'Juvenile Delinquency Film', 'Natural disaster', 'Dance',
#        'Movie serial', 'Comedy of manners', "Children's", 'Comedy horror',
#        'Remake', 'Media Satire', 'Computer Animation', 'Dogme 95',
#        'Law & Crime', 'Stop motion', 'Art film',
#        'Roadshow theatrical release', 'Sex comedy', 'Holiday Film',
#        'Heavenly Comedy', 'Road movie', 'Auto racing', 'Heist',
#        'Experimental film', 'Surrealism', 'Avant-garde', 'Archaeology',
#        'Romantic fantasy', 'Religious Film', 'Biker Film',
#        'Comedy of Errors', 'Absurdism', 'Domestic Comedy',
#        'Slice of life story', 'Hardcore pornography', 'Adult',
#        'Existentialism', 'Animated Musical', 'Cavalry Film',
#        'Haunted House Film', 'Costume Adventure', 'Adventure Comedy',
#        'Space opera', 'Dystopia', 'Animals', 'Addiction Drama',
#        'Anthropology', 'Educational', 'Chase Movie', 'Extreme Sports',
#        'Christian film', 'Hagiography', 'Social problem film',
#        'Superhero', 'Anti-war', 'Anti-war film', 'Gay pornography',
#        'Environmental Science',
#        'Apocalyptic and post-apocalyptic fiction',
#        'Airplanes and airports', 'Alien Film', 'Animal Picture',
#        'Animated cartoon', 'Film & Television History', 'Hybrid Western',
#        'Inspirational Drama', 'Revisionist Western', 'Medical fiction',
#        'Stand-up comedy', 'Jungle Film', 'Fairy tale', 'Punk rock',
#        'Libraries and librarians', 'Workplace Comedy', 'Caper story',
#        'Swashbuckler films', 'Demonic child', 'Illnesses & Disabilities',
#        'Expressionism', 'Early Black Cinema', 'Political satire',
#        'Comedy Thriller', 'Interpersonal Relationships', 'Whodunit',
#        'Sword and sorcery films', 'B-Western', 'Filmed Play', 'Northern',
#        'Hip hop movies', 'Film', 'Roadshow/Carny', 'Exploitation',
#        'Nature', 'Travel', 'Mumblecore', 'Glamorized Spy Film',
#        "Children's Entertainment", 'Anime', 'Star vehicle', 'Business',
#        'Journalism', 'Graphic & Applied Arts', 'Camp', 'Boxing',
#        'Sword and Sandal', 'Sci-Fi Adventure', 'Alien invasion',
#        'Sponsored film', 'Foreign legion', 'Pornography',
#        'Heaven-Can-Wait Fantasies', 'Tragicomedy',
#        'Women in prison films', 'Stoner film', 'Baseball', 'Prison film',
#        'Monster', 'Conspiracy fiction', 'Master Criminal Films',
#        'Jukebox musical', 'Indian Western', 'Mythological Fantasy',
#        'Road-Horror', 'Werewolf fiction', 'Neo-noir',
#        'Private military company', 'Finance & Investing', 'Computers',
#        'Backstage Musical', 'Movies About Gladiators', 'Horse racing',
#        'Nuclear warfare', 'Inventions & Innovations',
#        'Instrumental Music', 'Archives and records', 'Psycho-biddy',
#        'Filipino Movies', 'Outlaw biker film', 'Prison escape',
#        'Spaghetti Western', 'Z movie', 'News', 'Beach Film',
#        'Live action', 'Education', 'Health & Fitness',
#        'Science fiction Western', 'Bloopers & Candid Camera',
#        'Media Studies', 'Crime', 'Costume Horror', 'Psychological horror',
#        'Albino bias', 'Mondo film', 'Family & Personal Relationships',
#        'Steampunk', 'Buddy cop', 'Fantasy Drama', 'Sci-Fi Thriller',
#        'Courtroom Comedy', 'Language & Literature', 'Operetta',
#        'Cyberpunk', 'Coming-of-age film', 'Historical Documentaries',
#        'Cold War', 'Essay Film', 'British Empire Film', 'World History',
#        'Splatter film', "Children's Issues", 'Female buddy film',
#        'Race movie', 'Breakdance', 'Acid western', 'War effort',
#        'Bollywood', 'Reboot', 'Humour', 'School story',
#        'Sci Fi Pictures original films', 'Gulf War', 'Outlaw',
#        'Feature film', 'Kafkaesque', 'Vampire movies', 'Goat gland',
#        'Therimin music', 'Beach Party film', 'Fictional film',
#        'Singing cowboy', 'Point of view shot', 'Clay animation',
#        'Parkour in popular culture', 'Patriotic film', 'Anthology',
#        'Chick flick', 'Ealing Comedies', 'Samurai cinema',
#        'Political Documetary', 'Ninja movie', 'Statutory rape', 'Giallo',
#        'British New Wave', 'Supermarionation', 'Period Horror',
#        'The Netherlands in World War II', 'Revisionist Fairy Tale'],
#       dtype=object)

# %% [markdown]
# As we can see we have a massive amount (342) of genres, so at some point we will need to filter or chose certain genres to analyze.

# %% [markdown]
# **Plot of the number of movies per year**

# %%
# Let us first exclude movies that have an unknown release date (this is only for the sake of this plot, we will complement later if needed)
movies = us_english_movie_with_nan_metadata.dropna(subset=['release_date']).copy()
movies['release_date'] = movies['release_date'].astype(str)
movies['release_date'] = pd.to_datetime(movies['release_date'],format='mixed', errors='coerce')

# Group movies by release year
movies_grouped_by_year = movies.groupby(movies['release_date'].dt.year)

#number of movies per year
number_movies_per_year = movies_grouped_by_year.size()

plt.figure(figsize=(10, 6))
number_movies_per_year.plot(kind='line', color = 'cornflowerblue')
plt.title('Number of Movies Released per Year')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.grid(True)
plt.show()

# %%
display(movies)
# Out:
#        wikipedia_ID freebase_ID  \
# 0            975900   /m/03vyhn
# 1           3196793   /m/08yl5d
# 5          13696889  /m/03cfc81
# 7          10408933  /m/02qc0j7
# 10           175026   /m/017n1p
# ...             ...         ...
# 81725       1918494   /m/0660qx
# 81726        664006   /m/030xw6
# 81727      24209227  /m/07k5mlk
# 81736      35228177  /m/0j7hxnt
# 81738       9971909  /m/02pygw1
#
#                                                     name release_date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 5                                          The Gangsters   1913-05-29
# 7                               Alexander's Ragtime Band   1938-08-16
# 10                                         Sarah and Son   1930-01-01
# ...                                                  ...          ...
# 81725                                     State and Main   2000-08-26
# 81726                                      Guilty as Sin   1993-06-04
# 81727                   The Time, the Place and the Girl   1946-01-01
# 81736                           Mermaids: The Body Found   2011-03-19
# 81738                                  Another Nice Mess   1972-09-22
#
#        box_office_revenue  runtime                             languages  \
# 0              14010832.0     98.0                    [English Language]
# 1                     NaN     95.0                    [English Language]
# 5                     NaN     35.0       [Silent film, English Language]
# 7               3600000.0    106.0                    [English Language]
# 10                    NaN     86.0                    [English Language]
# ...                   ...      ...                                   ...
# 81725           6944471.0    106.0  [Italian Language, English Language]
# 81726          22886222.0    107.0                                    []
# 81727                 NaN    105.0                    [English Language]
# 81736                 NaN    120.0                    [English Language]
# 81738                 NaN     66.0                    [English Language]
#
#                                 countries  \
# 0              [United States of America]
# 1              [United States of America]
# 5              [United States of America]
# 7              [United States of America]
# 10             [United States of America]
# ...                                   ...
# 81725  [France, United States of America]
# 81726          [United States of America]
# 81727          [United States of America]
# 81736          [United States of America]
# 81738          [United States of America]
#
#                                                    genre
# 0      [Thriller, Science Fiction, Horror, Adventure,...
# 1       [Mystery, Biographical film, Drama, Crime Drama]
# 5      [Short Film, Silent film, Indie, Black-and-whi...
# 7                     [Musical, Comedy, Black-and-white]
# 10                              [Drama, Black-and-white]
# ...                                                  ...
# 81725                        [Parody, Americana, Comedy]
# 81726  [Thriller, Erotic thriller, Psychological thri...
# 81727               [Comedy film, Romance Film, Musical]
# 81736                                            [Drama]
# 81738                                   [Satire, Comedy]
#
# [32886 rows x 9 columns]

# %% [markdown]
# Let us merge this movies dataframe with the synopses

# %%
us_english_movies_synopsis = pd.merge(movies, plot_summaries, how='left', on = 'wikipedia_ID')

# %%
us_english_movies_synopsis
# Out:
#        wikipedia_ID freebase_ID  \
# 0            975900   /m/03vyhn
# 1           3196793   /m/08yl5d
# 2          13696889  /m/03cfc81
# 3          10408933  /m/02qc0j7
# 4            175026   /m/017n1p
# ...             ...         ...
# 32881       1918494   /m/0660qx
# 32882        664006   /m/030xw6
# 32883      24209227  /m/07k5mlk
# 32884      35228177  /m/0j7hxnt
# 32885       9971909  /m/02pygw1
#
#                                                     name release_date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                          The Gangsters   1913-05-29
# 3                               Alexander's Ragtime Band   1938-08-16
# 4                                          Sarah and Son   1930-01-01
# ...                                                  ...          ...
# 32881                                     State and Main   2000-08-26
# 32882                                      Guilty as Sin   1993-06-04
# 32883                   The Time, the Place and the Girl   1946-01-01
# 32884                           Mermaids: The Body Found   2011-03-19
# 32885                                  Another Nice Mess   1972-09-22
#
#        box_office_revenue  runtime                             languages  \
# 0              14010832.0     98.0                    [English Language]
# 1                     NaN     95.0                    [English Language]
# 2                     NaN     35.0       [Silent film, English Language]
# 3               3600000.0    106.0                    [English Language]
# 4                     NaN     86.0                    [English Language]
# ...                   ...      ...                                   ...
# 32881           6944471.0    106.0  [Italian Language, English Language]
# 32882          22886222.0    107.0                                    []
# 32883                 NaN    105.0                    [English Language]
# 32884                 NaN    120.0                    [English Language]
# 32885                 NaN     66.0                    [English Language]
#
#                                 countries  \
# 0              [United States of America]
# 1              [United States of America]
# 2              [United States of America]
# 3              [United States of America]
# 4              [United States of America]
# ...                                   ...
# 32881  [France, United States of America]
# 32882          [United States of America]
# 32883          [United States of America]
# 32884          [United States of America]
# 32885          [United States of America]
#
#                                                    genre  \
# 0      [Thriller, Science Fiction, Horror, Adventure,...
# 1       [Mystery, Biographical film, Drama, Crime Drama]
# 2      [Short Film, Silent film, Indie, Black-and-whi...
# 3                     [Musical, Comedy, Black-and-white]
# 4                               [Drama, Black-and-white]
# ...                                                  ...
# 32881                        [Parody, Americana, Comedy]
# 32882  [Thriller, Erotic thriller, Psychological thri...
# 32883               [Comedy film, Romance Film, Musical]
# 32884                                            [Drama]
# 32885                                   [Satire, Comedy]
#
#                                             plot_summary
# 0      Set in the second half of the 22nd century, th...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 32881  Havoc is wrought on the inhabitants of a small...
# 32882  Jennifer Haines  is an up-and-coming Chicago a...
# 32883                                                NaN
# 32884  Two former National Oceanic Atmospheric Admini...
# 32885                                                NaN
#
# [32886 rows x 10 columns]

# %% [markdown]
# Do we have a lot of missing summaries?

# %%
missing_plot = us_english_movies_synopsis['plot_summary'].isna().sum()
number_of_movies = len(us_english_movies_synopsis['plot_summary'])
print('We only have', number_of_movies- missing_plot, 'movies out of',number_of_movies, "with a summary, which means we only have 60.59% of the movies with the plot line" )
# Out:
# We only have 20105 movies out of 32886 with a summary, which means we only have 60.59% of the movies with the plot line

# %% [markdown]
# Creating a final dataset without NaN in the language column and without NaN in the release date

# %%
us_english_movies_metadata
# Out:
#        wikipedia_ID freebase_ID  \
# 0            975900   /m/03vyhn
# 1           3196793   /m/08yl5d
# 5          13696889  /m/03cfc81
# 7          10408933  /m/02qc0j7
# 10           175026   /m/017n1p
# ...             ...         ...
# 81721      34474142  /m/0cpy07r
# 81725       1918494   /m/0660qx
# 81727      24209227  /m/07k5mlk
# 81736      35228177  /m/0j7hxnt
# 81738       9971909  /m/02pygw1
#
#                                                     name release_date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 5                                          The Gangsters   1913-05-29
# 7                               Alexander's Ragtime Band   1938-08-16
# 10                                         Sarah and Son         1930
# ...                                                  ...          ...
# 81721                                      Frontier Fury   1943-06-24
# 81725                                     State and Main   2000-08-26
# 81727                   The Time, the Place and the Girl         1946
# 81736                           Mermaids: The Body Found   2011-03-19
# 81738                                  Another Nice Mess   1972-09-22
#
#        box_office_revenue  runtime                             languages  \
# 0              14010832.0     98.0                    [English Language]
# 1                     NaN     95.0                    [English Language]
# 5                     NaN     35.0       [Silent film, English Language]
# 7               3600000.0    106.0                    [English Language]
# 10                    NaN     86.0                    [English Language]
# ...                   ...      ...                                   ...
# 81721                 NaN     55.0                    [English Language]
# 81725           6944471.0    106.0  [Italian Language, English Language]
# 81727                 NaN    105.0                    [English Language]
# 81736                 NaN    120.0                    [English Language]
# 81738                 NaN     66.0                    [English Language]
#
#                                 countries  \
# 0              [United States of America]
# 1              [United States of America]
# 5              [United States of America]
# 7              [United States of America]
# 10             [United States of America]
# ...                                   ...
# 81721          [United States of America]
# 81725  [France, United States of America]
# 81727          [United States of America]
# 81736          [United States of America]
# 81738          [United States of America]
#
#                                                    genre
# 0      [Thriller, Science Fiction, Horror, Adventure,...
# 1       [Mystery, Biographical film, Drama, Crime Drama]
# 5      [Short Film, Silent film, Indie, Black-and-whi...
# 7                     [Musical, Comedy, Black-and-white]
# 10                              [Drama, Black-and-white]
# ...                                                  ...
# 81721                                          [Western]
# 81725                        [Parody, Americana, Comedy]
# 81727               [Comedy film, Romance Film, Musical]
# 81736                                            [Drama]
# 81738                                   [Satire, Comedy]
#
# [30528 rows x 9 columns]

# %%
us_movies_no_nan = us_english_movies_metadata.dropna(subset=['release_date']).copy()
us_movies_no_nan['release_date'] = us_movies_no_nan['release_date'].astype(str)
us_movies_no_nan['release_date'] = pd.to_datetime(us_movies_no_nan['release_date'],format='mixed', errors='coerce')
us_movies_no_nan
# Out:
#        wikipedia_ID freebase_ID  \
# 0            975900   /m/03vyhn
# 1           3196793   /m/08yl5d
# 5          13696889  /m/03cfc81
# 7          10408933  /m/02qc0j7
# 10           175026   /m/017n1p
# ...             ...         ...
# 81721      34474142  /m/0cpy07r
# 81725       1918494   /m/0660qx
# 81727      24209227  /m/07k5mlk
# 81736      35228177  /m/0j7hxnt
# 81738       9971909  /m/02pygw1
#
#                                                     name release_date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 5                                          The Gangsters   1913-05-29
# 7                               Alexander's Ragtime Band   1938-08-16
# 10                                         Sarah and Son   1930-01-01
# ...                                                  ...          ...
# 81721                                      Frontier Fury   1943-06-24
# 81725                                     State and Main   2000-08-26
# 81727                   The Time, the Place and the Girl   1946-01-01
# 81736                           Mermaids: The Body Found   2011-03-19
# 81738                                  Another Nice Mess   1972-09-22
#
#        box_office_revenue  runtime                             languages  \
# 0              14010832.0     98.0                    [English Language]
# 1                     NaN     95.0                    [English Language]
# 5                     NaN     35.0       [Silent film, English Language]
# 7               3600000.0    106.0                    [English Language]
# 10                    NaN     86.0                    [English Language]
# ...                   ...      ...                                   ...
# 81721                 NaN     55.0                    [English Language]
# 81725           6944471.0    106.0  [Italian Language, English Language]
# 81727                 NaN    105.0                    [English Language]
# 81736                 NaN    120.0                    [English Language]
# 81738                 NaN     66.0                    [English Language]
#
#                                 countries  \
# 0              [United States of America]
# 1              [United States of America]
# 5              [United States of America]
# 7              [United States of America]
# 10             [United States of America]
# ...                                   ...
# 81721          [United States of America]
# 81725  [France, United States of America]
# 81727          [United States of America]
# 81736          [United States of America]
# 81738          [United States of America]
#
#                                                    genre
# 0      [Thriller, Science Fiction, Horror, Adventure,...
# 1       [Mystery, Biographical film, Drama, Crime Drama]
# 5      [Short Film, Silent film, Indie, Black-and-whi...
# 7                     [Musical, Comedy, Black-and-white]
# 10                              [Drama, Black-and-white]
# ...                                                  ...
# 81721                                          [Western]
# 81725                        [Parody, Americana, Comedy]
# 81727               [Comedy film, Romance Film, Musical]
# 81736                                            [Drama]
# 81738                                   [Satire, Comedy]
#
# [29830 rows x 9 columns]

# %%
#merge with synopses

us_movies_no_nan = pd.merge(us_movies_no_nan, plot_summaries, how='left', on = 'wikipedia_ID')
us_movies_no_nan
# Out:
#        wikipedia_ID freebase_ID  \
# 0            975900   /m/03vyhn
# 1           3196793   /m/08yl5d
# 2          13696889  /m/03cfc81
# 3          10408933  /m/02qc0j7
# 4            175026   /m/017n1p
# ...             ...         ...
# 29825      34474142  /m/0cpy07r
# 29826       1918494   /m/0660qx
# 29827      24209227  /m/07k5mlk
# 29828      35228177  /m/0j7hxnt
# 29829       9971909  /m/02pygw1
#
#                                                     name release_date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                          The Gangsters   1913-05-29
# 3                               Alexander's Ragtime Band   1938-08-16
# 4                                          Sarah and Son   1930-01-01
# ...                                                  ...          ...
# 29825                                      Frontier Fury   1943-06-24
# 29826                                     State and Main   2000-08-26
# 29827                   The Time, the Place and the Girl   1946-01-01
# 29828                           Mermaids: The Body Found   2011-03-19
# 29829                                  Another Nice Mess   1972-09-22
#
#        box_office_revenue  runtime                             languages  \
# 0              14010832.0     98.0                    [English Language]
# 1                     NaN     95.0                    [English Language]
# 2                     NaN     35.0       [Silent film, English Language]
# 3               3600000.0    106.0                    [English Language]
# 4                     NaN     86.0                    [English Language]
# ...                   ...      ...                                   ...
# 29825                 NaN     55.0                    [English Language]
# 29826           6944471.0    106.0  [Italian Language, English Language]
# 29827                 NaN    105.0                    [English Language]
# 29828                 NaN    120.0                    [English Language]
# 29829                 NaN     66.0                    [English Language]
#
#                                 countries  \
# 0              [United States of America]
# 1              [United States of America]
# 2              [United States of America]
# 3              [United States of America]
# 4              [United States of America]
# ...                                   ...
# 29825          [United States of America]
# 29826  [France, United States of America]
# 29827          [United States of America]
# 29828          [United States of America]
# 29829          [United States of America]
#
#                                                    genre  \
# 0      [Thriller, Science Fiction, Horror, Adventure,...
# 1       [Mystery, Biographical film, Drama, Crime Drama]
# 2      [Short Film, Silent film, Indie, Black-and-whi...
# 3                     [Musical, Comedy, Black-and-white]
# 4                               [Drama, Black-and-white]
# ...                                                  ...
# 29825                                          [Western]
# 29826                        [Parody, Americana, Comedy]
# 29827               [Comedy film, Romance Film, Musical]
# 29828                                            [Drama]
# 29829                                   [Satire, Comedy]
#
#                                             plot_summary
# 0      Set in the second half of the 22nd century, th...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 29825                                                NaN
# 29826  Havoc is wrought on the inhabitants of a small...
# 29827                                                NaN
# 29828  Two former National Oceanic Atmospheric Admini...
# 29829                                                NaN
#
# [29830 rows x 10 columns]

# %%
#save this df in a CSV
us_movies_no_nan.to_csv('us_movies', index=False)
