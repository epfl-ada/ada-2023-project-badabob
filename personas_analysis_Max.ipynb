# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from collections import Counter
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
#nltk.download('wordnet')
from nltk.stem import PorterStemmer
from tqdm import tqdm

# %%
#import spacy

# %%
personas_data = pickle.load(open("pickles/final.pickle", "rb")) # SHOULD BE IN FOLDER PICKLE SO TO MODIFY!

# %%
display(personas_data)
# Out:
#         character_ID  wikipedia_ID freebase_ID actor_ethnicity  \
# 0                  1      975900.0   /m/03vyhn             NaN
# 1                  2      975900.0   /m/03vyhn      /m/044038p
# 2                  3      975900.0   /m/03vyhn         /m/0x67
# 3                  4      975900.0   /m/03vyhn             NaN
# 4                  5      975900.0   /m/03vyhn             NaN
# ...              ...           ...         ...             ...
# 336453        336454           NaN         NaN             NaN
# 336454        336455           NaN         NaN             NaN
# 336455        336456           NaN         NaN             NaN
# 336456        336457           NaN         NaN             NaN
# 336457        336458           NaN         NaN             NaN
#
#                 actor_name personnas    IMDB_ID              character_name  \
# 0           wanda de jesus       NaN  tt0228333                    Akooshay
# 1       natasha henstridge       NaN  tt0228333  Lieutenant Melanie Ballard
# 2                 ice cube       NaN  tt0228333         Desolation Williams
# 3            jason statham       NaN  tt0228333          Sgt Jericho Butler
# 4              clea duvall       NaN  tt0228333             Bashira Kincaid
# ...                    ...       ...        ...                         ...
# 336453       caleb silvers       NaN  tt9914522                        Evan
# 336454    bethany hazelitt       NaN  tt9914522                   Mackenzie
# 336455        joshua bootz       NaN  tt9914522                  Evan's dad
# 336456         vince camaj       NaN  tt9914522                        Todd
# 336457      sandra gendjar       NaN  tt9914522                      Kelsey
#
#        actor_gender  box_office_revenue                    name  release_date  \
# 0                 F                 NaN          Ghosts of Mars        2001.0
# 1                 F          14010832.0          Ghosts of Mars        2001.0
# 2                 M          14010832.0          Ghosts of Mars        2001.0
# 3                 M          14010832.0          Ghosts of Mars        2001.0
# 4                 F                 NaN          Ghosts of Mars        2001.0
# ...             ...                 ...                     ...           ...
# 336453            M                 NaN  The Holden Family Plan        2019.0
# 336454            F                 NaN  The Holden Family Plan        2019.0
# 336455            M                 NaN  The Holden Family Plan        2019.0
# 336456            M                 NaN  The Holden Family Plan        2019.0
# 336457            F                 NaN  The Holden Family Plan        2019.0
#
#         actor_age                                              Verbs  \
# 0            42.0                       [discovered, created, wiped]
# 1            27.0  [terraformed, allowing, become, authority, sen...
# 2            32.0  [wearing, become, named, named, held, mining, ...
# 3            34.0  [walk, wearing, sent, opened, released, posses...
# 4            23.0  [killed, returning, blame, cot, escapes, leaving]
# ...           ...                                                ...
# 336453       24.0                                  [make, regarding]
# 336454       29.0             [murdered, regarding, make, regarding]
# 336455        NaN                       [make, regarding, regarding]
# 336456        NaN                                                NaN
# 336457        NaN                                                NaN
#
#                                                Adjectives  \
# 0                         [second, 22nd, ancient, fierce]
# 1       [matriarchal, police, second, second, small, s...
# 2       [transport, remote, ancient, horrific, team, d...
# 3       [second, pick, disembodied, possible, Unfortun...
# 4                                              [massacre]
# ...                                                   ...
# 336453                                              [new]
# 336454                                       [new, niece]
# 336455                                              [new]
# 336456                                                NaN
# 336457                                                NaN
#
#                                                     Nouns  \
# 0       [Set, century, film, miners, Martian, miners, ...
# 1       [film, depicts, Mars, positions, story, concer...
# 2       [pressure, suits, society, prisoner, Williams,...
# 3       [half, humans, surface, pressure, suits, team,...
# 4       [pick, transport, prisoner, Desolation, Willia...
# ...                                                   ...
# 336453                     [Mackenzie, husband, decision]
# 336454  [Holden, sister, brother, law, husband, Evan, ...
# 336455        [Mackenzie, husband, decision, make, niece]
# 336456                                                NaN
# 336457                                                NaN
#
#                                                    Chunks
# 0       [[(Set, NNP)], (second, JJ), (22nd, JJ), (cent...
# 1       [(film, NN), (depicts, NNS), (Mars, NNP), (84,...
# 2       [(wearing, VBG), (pressure, NN), (suits, NNS),...
# 3       [(second, JJ), (half, NN), (22nd, CD), (humans...
# 4       [(pick, NN), (transport, NN), (prisoner, NN), ...
# ...                                                   ...
# 336453  [[(Mackenzie, NNP)], (new, JJ), (husband, NN),...
# 336454  [[(Holden, NNP)], (sister, NN), (brother, NN),...
# 336455  [[(Mackenzie, NNP)], (new, JJ), (husband, NN),...
# 336456                                                NaN
# 336457                                                NaN
#
# [336458 rows x 17 columns]

# %%
# we drop the characters that have no words associated to them -  they do not appear in summaries
personas_noNA = personas_data.dropna(subset="Chunks")
display(personas_noNA)
# Out:
#         character_ID  wikipedia_ID freebase_ID actor_ethnicity  \
# 0                  1      975900.0   /m/03vyhn             NaN
# 1                  2      975900.0   /m/03vyhn      /m/044038p
# 2                  3      975900.0   /m/03vyhn         /m/0x67
# 3                  4      975900.0   /m/03vyhn             NaN
# 4                  5      975900.0   /m/03vyhn             NaN
# ...              ...           ...         ...             ...
# 336450        336451           NaN         NaN             NaN
# 336452        336453           NaN         NaN             NaN
# 336453        336454           NaN         NaN             NaN
# 336454        336455           NaN         NaN             NaN
# 336455        336456           NaN         NaN             NaN
#
#                 actor_name personnas    IMDB_ID              character_name  \
# 0           wanda de jesus       NaN  tt0228333                    Akooshay
# 1       natasha henstridge       NaN  tt0228333  Lieutenant Melanie Ballard
# 2                 ice cube       NaN  tt0228333         Desolation Williams
# 3            jason statham       NaN  tt0228333          Sgt Jericho Butler
# 4              clea duvall       NaN  tt0228333             Bashira Kincaid
# ...                    ...       ...        ...                         ...
# 336450  jeffrey sieverding       NaN  tt9913288                    Mail Man
# 336452      tenley kellogg       NaN  tt9914522                        Jade
# 336453       caleb silvers       NaN  tt9914522                        Evan
# 336454    bethany hazelitt       NaN  tt9914522                   Mackenzie
# 336455        joshua bootz       NaN  tt9914522                  Evan's dad
#
#        actor_gender  box_office_revenue                    name  release_date  \
# 0                 F                 NaN          Ghosts of Mars        2001.0
# 1                 F          14010832.0          Ghosts of Mars        2001.0
# 2                 M          14010832.0          Ghosts of Mars        2001.0
# 3                 M          14010832.0          Ghosts of Mars        2001.0
# 4                 F                 NaN          Ghosts of Mars        2001.0
# ...             ...                 ...                     ...           ...
# 336450            M                 NaN                 Letters        2020.0
# 336452            F                 NaN  The Holden Family Plan        2019.0
# 336453            M                 NaN  The Holden Family Plan        2019.0
# 336454            F                 NaN  The Holden Family Plan        2019.0
# 336455            M                 NaN  The Holden Family Plan        2019.0
#
#         actor_age                                              Verbs  \
# 0            42.0                       [discovered, created, wiped]
# 1            27.0  [terraformed, allowing, become, authority, sen...
# 2            32.0  [wearing, become, named, named, held, mining, ...
# 3            34.0  [walk, wearing, sent, opened, released, posses...
# 4            23.0  [killed, returning, blame, cot, escapes, leaving]
# ...           ...                                                ...
# 336450        NaN                                           [stands]
# 336452        NaN                                             [make]
# 336453       24.0                                  [make, regarding]
# 336454       29.0             [murdered, regarding, make, regarding]
# 336455        NaN                       [make, regarding, regarding]
#
#                                                Adjectives  \
# 0                         [second, 22nd, ancient, fierce]
# 1       [matriarchal, police, second, second, small, s...
# 2       [transport, remote, ancient, horrific, team, d...
# 3       [second, pick, disembodied, possible, Unfortun...
# 4                                              [massacre]
# ...                                                   ...
# 336450                                 [ordinary, normal]
# 336452                                              [new]
# 336453                                              [new]
# 336454                                       [new, niece]
# 336455                                              [new]
#
#                                                     Nouns  \
# 0       [Set, century, film, miners, Martian, miners, ...
# 1       [film, depicts, Mars, positions, story, concer...
# 2       [pressure, suits, society, prisoner, Williams,...
# 3       [half, humans, surface, pressure, suits, team,...
# 4       [pick, transport, prisoner, Desolation, Willia...
# ...                                                   ...
# 336450  [Charlie, Porter, leads, life, home, get, bill...
# 336452  [honeymoon, Mackenzie, Evan, decision, make, r...
# 336453                     [Mackenzie, husband, decision]
# 336454  [Holden, sister, brother, law, husband, Evan, ...
# 336455        [Mackenzie, husband, decision, make, niece]
#
#                                                    Chunks
# 0       [[(Set, NNP)], (second, JJ), (22nd, JJ), (cent...
# 1       [(film, NN), (depicts, NNS), (Mars, NNP), (84,...
# 2       [(wearing, VBG), (pressure, NN), (suits, NNS),...
# 3       [(second, JJ), (half, NN), (22nd, CD), (humans...
# 4       [(pick, NN), (transport, NN), (prisoner, NN), ...
# ...                                                   ...
# 336450  [[(Charlie, NNP)], [(Porter, NNP)], (ordinary,...
# 336452  [(honeymoon, NN), [(Mackenzie, NNP)], (new, JJ...
# 336453  [[(Mackenzie, NNP)], (new, JJ), (husband, NN),...
# 336454  [[(Holden, NNP)], (sister, NN), (brother, NN),...
# 336455  [[(Mackenzie, NNP)], (new, JJ), (husband, NN),...
#
# [168330 rows x 17 columns]

# %%
# Check the type of the first element in each column to make sure they were saved properly
first_verb = type(personas_noNA['Verbs'][0])
first_noun = type(personas_noNA['Nouns'][0])
first_adjective = type(personas_noNA['Adjectives'][0])

print(f'Type of the first element in Verbs column: {first_verb}')
print(f'Type of the first element in Nouns column: {first_noun}')
print(f'Type of the first element in Adjectives column: {first_adjective}')
# Out:
# Type of the first element in Verbs column: <class 'list'>
# Type of the first element in Nouns column: <class 'list'>
# Type of the first element in Adjectives column: <class 'list'>

# %%
# create a column "decade" to do the analysis on decades and not years
final_personas_df = personas_noNA.copy()
final_personas_df['decade'] = final_personas_df['release_date'] // 10 * 10
display(final_personas_df)
# Out:
#         character_ID  wikipedia_ID freebase_ID actor_ethnicity  \
# 0                  1      975900.0   /m/03vyhn             NaN
# 1                  2      975900.0   /m/03vyhn      /m/044038p
# 2                  3      975900.0   /m/03vyhn         /m/0x67
# 3                  4      975900.0   /m/03vyhn             NaN
# 4                  5      975900.0   /m/03vyhn             NaN
# ...              ...           ...         ...             ...
# 336450        336451           NaN         NaN             NaN
# 336452        336453           NaN         NaN             NaN
# 336453        336454           NaN         NaN             NaN
# 336454        336455           NaN         NaN             NaN
# 336455        336456           NaN         NaN             NaN
#
#                 actor_name personnas    IMDB_ID              character_name  \
# 0           wanda de jesus       NaN  tt0228333                    Akooshay
# 1       natasha henstridge       NaN  tt0228333  Lieutenant Melanie Ballard
# 2                 ice cube       NaN  tt0228333         Desolation Williams
# 3            jason statham       NaN  tt0228333          Sgt Jericho Butler
# 4              clea duvall       NaN  tt0228333             Bashira Kincaid
# ...                    ...       ...        ...                         ...
# 336450  jeffrey sieverding       NaN  tt9913288                    Mail Man
# 336452      tenley kellogg       NaN  tt9914522                        Jade
# 336453       caleb silvers       NaN  tt9914522                        Evan
# 336454    bethany hazelitt       NaN  tt9914522                   Mackenzie
# 336455        joshua bootz       NaN  tt9914522                  Evan's dad
#
#        actor_gender  box_office_revenue                    name  release_date  \
# 0                 F                 NaN          Ghosts of Mars        2001.0
# 1                 F          14010832.0          Ghosts of Mars        2001.0
# 2                 M          14010832.0          Ghosts of Mars        2001.0
# 3                 M          14010832.0          Ghosts of Mars        2001.0
# 4                 F                 NaN          Ghosts of Mars        2001.0
# ...             ...                 ...                     ...           ...
# 336450            M                 NaN                 Letters        2020.0
# 336452            F                 NaN  The Holden Family Plan        2019.0
# 336453            M                 NaN  The Holden Family Plan        2019.0
# 336454            F                 NaN  The Holden Family Plan        2019.0
# 336455            M                 NaN  The Holden Family Plan        2019.0
#
#         actor_age                                              Verbs  \
# 0            42.0                       [discovered, created, wiped]
# 1            27.0  [terraformed, allowing, become, authority, sen...
# 2            32.0  [wearing, become, named, named, held, mining, ...
# 3            34.0  [walk, wearing, sent, opened, released, posses...
# 4            23.0  [killed, returning, blame, cot, escapes, leaving]
# ...           ...                                                ...
# 336450        NaN                                           [stands]
# 336452        NaN                                             [make]
# 336453       24.0                                  [make, regarding]
# 336454       29.0             [murdered, regarding, make, regarding]
# 336455        NaN                       [make, regarding, regarding]
#
#                                                Adjectives  \
# 0                         [second, 22nd, ancient, fierce]
# 1       [matriarchal, police, second, second, small, s...
# 2       [transport, remote, ancient, horrific, team, d...
# 3       [second, pick, disembodied, possible, Unfortun...
# 4                                              [massacre]
# ...                                                   ...
# 336450                                 [ordinary, normal]
# 336452                                              [new]
# 336453                                              [new]
# 336454                                       [new, niece]
# 336455                                              [new]
#
#                                                     Nouns  \
# 0       [Set, century, film, miners, Martian, miners, ...
# 1       [film, depicts, Mars, positions, story, concer...
# 2       [pressure, suits, society, prisoner, Williams,...
# 3       [half, humans, surface, pressure, suits, team,...
# 4       [pick, transport, prisoner, Desolation, Willia...
# ...                                                   ...
# 336450  [Charlie, Porter, leads, life, home, get, bill...
# 336452  [honeymoon, Mackenzie, Evan, decision, make, r...
# 336453                     [Mackenzie, husband, decision]
# 336454  [Holden, sister, brother, law, husband, Evan, ...
# 336455        [Mackenzie, husband, decision, make, niece]
#
#                                                    Chunks  decade
# 0       [[(Set, NNP)], (second, JJ), (22nd, JJ), (cent...  2000.0
# 1       [(film, NN), (depicts, NNS), (Mars, NNP), (84,...  2000.0
# 2       [(wearing, VBG), (pressure, NN), (suits, NNS),...  2000.0
# 3       [(second, JJ), (half, NN), (22nd, CD), (humans...  2000.0
# 4       [(pick, NN), (transport, NN), (prisoner, NN), ...  2000.0
# ...                                                   ...     ...
# 336450  [[(Charlie, NNP)], [(Porter, NNP)], (ordinary,...  2020.0
# 336452  [(honeymoon, NN), [(Mackenzie, NNP)], (new, JJ...  2010.0
# 336453  [[(Mackenzie, NNP)], (new, JJ), (husband, NN),...  2010.0
# 336454  [[(Holden, NNP)], (sister, NN), (brother, NN),...  2010.0
# 336455  [[(Mackenzie, NNP)], (new, JJ), (husband, NN),...  2010.0
#
# [168330 rows x 18 columns]

# %%
final_personas_df_perso = final_personas_df.dropna(subset="personnas")
display(final_personas_df_perso)
# Out:
#         character_ID  wikipedia_ID freebase_ID actor_ethnicity  \
# 396              397      196176.0   /m/01bwgr        /m/041rx
# 1521            1522     1157158.0   /m/04c13q             NaN
# 1890            1891      504242.0   /m/02j9_2        /m/041rx
# 2231            2232     6917005.0   /m/0gwypk        /m/041rx
# 2810            2811      445066.0   /m/0299hs             NaN
# ...              ...           ...         ...             ...
# 223869        223870     2688769.0   /m/07y2zw             NaN
# 224649        224650      101954.0    /m/0pv3x        /m/0d7wh
# 224836        224837     9513043.0  /m/02ph9tm        /m/041rx
# 226978        226979       52549.0    /m/0dtfn       /m/01qhm_
# 228150        228151       43452.0    /m/0bx0l       /m/02g7sp
#
#                actor_name                    personnas    IMDB_ID  \
# 396        dustin hoffman                tranquil_fury  tt0067800
# 1521        edward norton               granola_person  tt0266452
# 1890      david krumholtz               playful_hacker  tt0379786
# 2231    matthew broderick                      charmer  tt0293437
# 2810            ronny cox  corrupt_corporate_executive  tt0093870
# ...                   ...                          ...        ...
# 223869  laura san giacomo                      ophelia  tt0102744
# 224649        colin firth            crazy_jealous_guy  tt0116209
# 224836       adam sandler                 warrior_poet  tt0960144
# 226978      harrison ford                      charmer  tt0076759
# 228150      peter o'toole                 warrior_poet  tt0056172
#
#                character_name actor_gender  box_office_revenue  \
# 396              David Sumner            M          11148828.0
# 1521            Sheldon Mopes            M           8382938.0
# 1890             Mr. Universe            M                 NaN
# 2231    Professor Harold Hill            M                 NaN
# 2810               Dick Jones            M          53424681.0
# ...                       ...          ...                 ...
# 223869             Crazy Cora            F          21413105.0
# 224649       Geoffrey Clifton            M                 NaN
# 224836                  Zohan            M         201802891.0
# 226978               Han Solo            M         775398007.0
# 228150               Lawrence            M                 NaN
#
#                                     name  release_date  actor_age  \
# 396                           Straw Dogs        1971.0       34.0
# 1521                    Death to Smoochy        2002.0       33.0
# 1890                            Serenity        2005.0       27.0
# 2231                       The Music Man        2003.0       41.0
# 2810                             RoboCop        1987.0       49.0
# ...                                  ...           ...        ...
# 223869                Quigley Down Under        1990.0       29.0
# 224649               The English Patient        1996.0       36.0
# 224836     You Don't Mess with the Zohan        2008.0       42.0
# 226978  Star Wars Episode IV: A New Hope        1977.0       35.0
# 228150                Lawrence of Arabia        1962.0       30.0
#
#                                                     Verbs  \
# 396     [differing, regarding, come, wants, earning, w...
# 1521    [replaced, providing, seen, hatches, bring, ho...
# 1890    [named, promising, tasked, neutralizing, visit...
# 2231    [con, makes, sitting, named, realizes, named, ...
# 2810    [run, headed, kills, kills, transferred, aband...
# ...                                                   ...
# 223869  [prevent, forcing, forcing, seeing, calls, bea...
# 224649  [brought, reveals, reveals, bolstered, joins, ...
# 224836  [respected, disenchanted, become, fighting, in...
# 226978  [stolen, captured, captured, knows, named, tak...
# 228150  [separated, killed, misfit, stationed, meets, ...
#
#                                                Adjectives  \
# 396     [timid, timid, American, young, tension, immer...
# 1521    [squeaky, clean, squeaky, clean, sincere, inte...
# 1890    [young, high, animalistic, animalistic, eat, n...
# 2231    [latest, anvil, fresh, fresh, anywhere, hotel,...
# 2810    [future, robotic, senior, senior, junior, prec...
# ...                                                   ...
# 223869  [unconsciousness, fourth, tragic, nearby, infa...
# 224649  [married, present, interrogated, German, patie...
# 224836  [finest, disgusted, disgusted, constant, sever...
# 226978  [Rebel, first, analyze, vulnerable, assault, r...
# 228150  [remarkable, enigmatic, little, British, notab...
#
#                                                     Nouns  \
# 396     [Sumner, American, David, mathematician, wife,...
# 1521    [Mopes, character, Smoochy, Sheldon, character...
# 1890    [girl, Tam, number, Operative, Alliance, Seren...
# 2231    [Harold, Hill, con, Professor, Hill, artist, P...
# 2810    [Detroit, Michigan, Omni, Consumer, Products, ...
# ...                                                   ...
# 223869  [tries, Cora, wagon, prevent, Crazy, wagon, be...
# 224649  [woman, Katharine, army, torture, addition, co...
# 224836  [Dvir, superhuman, Israeli, Zohan, Dvir, Israe...
# 226978  [Alliance, Galactic, Empire, Death, Princess, ...
# 228150  [intermission, motorcycle, accident, man, succ...
#
#                                                    Chunks  decade
# 396     [[(Sumner, NNP)], (timid, JJ), [(American, NNP...  1970.0
# 1521    [(replaced, VBN), (squeaky, JJ), (clean, JJ), ...  2000.0
# 1890    [(young, JJ), (girl, NN), (named, VBN), (Tam, ...  2000.0
# 2231    [[(Harold, NNP)], [(Hill, NNP)], (con, NN), (P...  2000.0
# 2810    [(future, JJ), [(Detroit, NNP), (Michigan, NNP...  1980.0
# ...                                                   ...     ...
# 223869  [(tries, NNS), (prevent, VBP), (forcing, VBG),...  1990.0
# 224649  [(married, JJ), (woman, NN), [(Katharine, NNP)...  1990.0
# 224836  [[(Dvir, NNP)], (superhuman, NN), [(Israeli, N...  2000.0
# 226978  [[(Rebel, JJ)], [(Alliance, NNP)], (stolen, VB...  1970.0
# 228150  [(separated, VBN), (intermission, NN), (1935, ...  1960.0
#
# [413 rows x 18 columns]

# %%
# sort the rows to have decades in ascending orders
final_personas_df = final_personas_df.sort_values(by='decade')

# %%
unique_decades = final_personas_df['decade'].unique() # control the order of the decades
print(unique_decades)
# Out:
# [1910. 1920. 1930. 1940. 1950. 1960. 1970. 1980. 1990. 2000. 2010. 2020.]

# %%
# group the movies by decade
personas_by_decade = final_personas_df.groupby(final_personas_df['decade'])
count_per_decade = personas_by_decade.size() # to have the number of characters per decade

plt.figure(figsize=(10, 6))
count_per_decade.plot(kind='line', color='skyblue', marker='o')
plt.title('Number of Character per Decade in the Dataset')
plt.xlabel('Decade')
plt.ylabel('Number of Characters')
plt.grid(True)
plt.show()

# %%
result_df = final_personas_df[final_personas_df.apply(lambda row: 'pregnant' in row['Verbs'] or 'pregnant' in row['Adjectives'] or 'pregnant' in row['Nouns'], axis=1)]

# Display the result
display(result_df)
# Out:
#         character_ID  wikipedia_ID freebase_ID actor_ethnicity  \
# 228984        228985           NaN         NaN             NaN
# 228985        228986           NaN         NaN             NaN
# 13928          13929    24486794.0  /m/080p7hm             NaN
# 107801        107802    14836345.0  /m/03gzmkj             NaN
# 13929          13930    24486794.0  /m/080p7hm             NaN
# ...              ...           ...         ...             ...
# 269741        269742           NaN         NaN             NaN
# 269161        269162           NaN         NaN             NaN
# 269162        269163           NaN         NaN             NaN
# 269163        269164           NaN         NaN             NaN
# 269164        269165           NaN         NaN             NaN
#
#                          actor_name personnas     IMDB_ID  \
# 228984                 lillian gish       NaN   tt0003170
# 228985                   kate bruce       NaN   tt0003170
# 13928             bessie barriscale       NaN   tt0006743
# 107801                walter miller       NaN   tt0003170
# 13929                   bruce mcrae       NaN   tt0006743
# ...                             ...       ...         ...
# 269741                 joe campbell       NaN  tt11856036
# 269161                  travis cure       NaN  tt11724384
# 269162              michelle l lamb       NaN  tt11724384
# 269163  alphonso a'qen-aten jackson       NaN  tt11724384
# 269164                monyetta shaw       NaN  tt11724384
#
#                  character_name actor_gender  box_office_revenue  \
# 228984           The Young Wife            F                 NaN
# 228985      Young Wife's Mother            F                 NaN
# 13928           Margery Allison            F                 NaN
# 107801  Joe - The Young Husband            M                 NaN
# 13929          Dr. Ward Allison            M                 NaN
# ...                         ...          ...                 ...
# 269741           Crew Member #3            M                 NaN
# 269161            Andrew Thomas            M                 NaN
# 269162            Lauren Thomas            F                 NaN
# 269163          Franklin Thomas            M                 NaN
# 269164          Mahogany Thomas            F                 NaN
#
#                           name  release_date  actor_age  \
# 228984     The Mothering Heart        1913.0       20.0
# 228985     The Mothering Heart        1913.0       53.0
# 13928          The Green Swamp        1916.0       32.0
# 107801     The Mothering Heart        1913.0       21.0
# 13929          The Green Swamp        1916.0       49.0
# ...                        ...           ...        ...
# 269741      Three Pregnant Men        2020.0        NaN
# 269161  I Wish I Never Met You        2022.0        NaN
# 269162  I Wish I Never Met You        2022.0        NaN
# 269163  I Wish I Never Met You        2022.0        NaN
# 269164  I Wish I Never Met You        2022.0        NaN
#
#                                                     Verbs  \
# 228984  [deserted, baby, born, goes, look, dying, find...
# 228985  [deserted, goes, goes, look, dying, finds, dyi...
# 13928         [fails, fails, deliver, learning, learning]
# 107801  [deserted, dies, goes, look, goes, look, finds...
# 13929        [fails, message, pleads, learning, learning]
# ...                                                   ...
# 269741                                          [follows]
# 269161  [turning, celebrating, take, escalate, gets, i...
# 269162                  [turning, celebrating, grow, met]
# 269163                               [turning, hits, met]
# 269164                  [turning, pregnant, friends, met]
#
#                                                Adjectives  \
# 228984                           [pregnant, child, child]
# 228985                           [pregnant, child, child]
# 13928   [friendship, female, deliver, female, patient,...
# 107801          [pregnant, child, child, child, realizes]
# 13929   [friendship, female, deliver, female, patient,...
# ...                                                   ...
# 269741              [documentary, first, pregnant, final]
# 269161    [true, military, pregnant, first, entire, Wish]
# 269162           [military, pregnant, first, tired, Wish]
# 269163           [due, military, first, proverbial, Wish]
# 269164  [military, first, pregnant, first, proverbial,...
#
#                                                     Nouns  \
# 228984  [husband, Walter, woman, husband, husband, fin...
# 228985  [husband, Walter, husband, affair, abandons, m...
# 13928   [film, centers, Allison, husband, Ward, film, ...
# 107801  [wife, Walter, Miller, woman, affair, abandons...
# 13929   [film, centers, Magery, husband, Ward, Magery,...
# ...                                                   ...
# 269741                                      [world, term]
# 269161  [provider, father, Thomas, brother, Franklin, ...
# 269162  [provider, father, Andrew, brother, Franklin, ...
# 269163  [provider, father, Andrew, brother, Franklin, ...
# 269164  [provider, father, Andrew, brother, Franklin, ...
#
#                                                    Chunks  decade
# 228984  [(pregnant, JJ), (deserted, VBD), (husband, NN...  1910.0
# 228985  [(pregnant, JJ), (deserted, VBD), (husband, NN...  1910.0
# 13928   [(film, NN), (centers, NNS), [(Allison, NNP)],...  1910.0
# 107801  [(pregnant, JJ), (wife, NN), (deserted, VBD), ...  1910.0
# 13929   [(film, NN), (centers, NNS), [(Magery, NNP)], ...  1910.0
# ...                                                   ...     ...
# 269741  [(documentary, JJ), (follows, VBZ), (world, NN...  2020.0
# 269161  [(turning, VBG), (40, CD), (one, CD), (true, J...  2020.0
# 269162  [(turning, VBG), (40, CD), (one, CD), (provide...  2020.0
# 269163  [(turning, VBG), (40, CD), (one, CD), (provide...  2020.0
# 269164  [(turning, VBG), (40, CD), (one, CD), (provide...  2020.0
#
# [2882 rows x 18 columns]

# %%
# Function to apply stemming to a list of words with a progress bar
def stem_words_with_progress(word_list):
    stemmer = PorterStemmer()
    stemmed_words = []
    for word in word_list:
        stemmed_words.append(stemmer.stem(word))
    return stemmed_words

# %%
# MAX RUN THIS PLEASE :)
tqdm.pandas(desc='Stemming')
final_personas_df['Verbs'] = final_personas_df['Verbs'].progress_apply(stem_words_with_progress)
display(final_personas_df)
# Out:
# Stemming: 100%|██████████| 168330/168330 [00:57<00:00, 2902.68it/s]
#         character_ID  wikipedia_ID freebase_ID actor_ethnicity  \
# 153634        153635     2543813.0   /m/07m2js             NaN
# 255623        255624           NaN         NaN             NaN
# 255622        255623           NaN         NaN             NaN
# 228973        228974           NaN         NaN             NaN
# 255616        255617           NaN         NaN             NaN
# ...              ...           ...         ...             ...
# 269063        269064           NaN         NaN             NaN
# 269064        269065           NaN         NaN             NaN
# 269069        269070           NaN         NaN             NaN
# 269071        269072           NaN         NaN             NaN
# 264529        264530           NaN         NaN             NaN
#
#                    actor_name personnas     IMDB_ID     character_name  \
# 153634         wesley ruggles       NaN   tt0007162   Client with Ring
# 255623          elsie macleod       NaN   tt0268913              Elsie
# 255622             billy ruge       NaN   tt0268913               Runt
# 228973            fay tincher       NaN   tt0003167  The Worldly Woman
# 255616            madge kirby       NaN   tt0268254       Larry's Wife
# ...                       ...       ...         ...                ...
# 269063            nefti boyer       NaN  tt11714398      Rude Customer
# 269064          winston green       NaN  tt11714398       The Stranger
# 269069        rockmond dunbar       NaN  tt11718330             Harold
# 269071           vernon davis       NaN  tt11718330             Daniel
# 264529  phillip andre botello       NaN  tt10816062             Albert
#
#        actor_gender  box_office_revenue                name  release_date  \
# 153634            M                 NaN        The Pawnshop        1916.0
# 255623            F                 NaN      All for a Girl        1916.0
# 255622            M                 NaN      All for a Girl        1916.0
# 228973            F                 NaN    Home, Sweet Home        1914.0
# 255616            F                 NaN  Dunces and Dangers        1918.0
# ...             ...                 ...                 ...           ...
# 269063            M                 NaN          Jacqueline        2021.0
# 269064            M                 NaN          Jacqueline        2021.0
# 269069            M                 NaN          Red Winter        2022.0
# 269071            M                 NaN          Red Winter        2022.0
# 264529            M                 NaN  The Dinner Parting        2022.0
#
#         actor_age                                              Verbs  \
# 153634        NaN  [fellow, examin, examin, pawnshop, dust, polis...
# 255623       26.0                                [agre, agre, marri]
# 255622       53.0                                           [obtain]
# 228973       30.0                                    [begin, career]
# 255616       34.0                                            [coupl]
# ...           ...                                                ...
# 269063        NaN                          [adulthood, emerg, decid]
# 269064        NaN           [abus, hand, decid, get, decid, unleash]
# 269069       49.0  [hit, arriv, learn, wit, learn, murder, hit, s...
# 269071       38.0                           [decid, mountain, decid]
# 264529        NaN              [host, tri, make, tri, make, concern]
#
#                                                Adjectives  \
# 153634  [burglar, dependable, assistant, pawnshop, fab...
# 255623                                       [interested]
# 255622                               [interested, better]
# 228973                                                 []
# 255616                                             [Next]
# ...                                                   ...
# 269063                               [mental, mysterious]
# 269064                             [shy, entire, control]
# 269069  [solitude, bitter, bitter, survival, solitude,...
# 269071                                                 []
# 264529               [good, good, recent, unravel, Susan]
#
#                                                     Nouns  \
# 153634  [competes, shop, capture, destroys, clock, det...
# 255623     [Plump, Runt, girl, Elsie, Runt, girl, suitor]
# 255622                          [Plump, girl, Elsie, job]
# 228973                      [home, encouragement, mother]
# 255616                   [man, trouble, group, men, lock]
# ...                                                   ...
# 269063          [father, abuse, personality, Jackie, get]
# 269064  [woman, discovers, life, abuse, Jackie, beast,...
# 269069  [cartel, men, Andrews, Daniel, Marx, solitude,...
# 269071  [men, Carla, Andrews, Marx, couple, rocky, rel...
# 264529                    [Henry, dinner, death, efforts]
#
#                                                    Chunks  decade
# 153634  [(competes, NNS), (fellow, VBP), (shop, NN), (...  1910.0
# 255623  [[(Plump, NNP)], [(Runt, NNP)], (girl, NN), [(...  1910.0
# 255622  [[(Plump, NNP)], (interested, JJ), (girl, NN),...  1910.0
# 228973  [(home, NN), (begins, VBZ), (career, VB), (Des...  1910.0
# 255616  [(man, NN), (trouble, NN), (financially, RB), ...  1910.0
# ...                                                   ...     ...
# 269063  [(father, NN), (mental, JJ), (abuse, NN), (adu...  2020.0
# 269064  [(shy, JJ), (woman, NN), (discovers, NNS), (ab...  2020.0
# 269069  [(cartel, NN), (hit, VBD), (men, NNS), [(Andre...  2020.0
# 269071  [(men, NNS), [(Carla, NNP), (Andrews, NNP), (M...  2020.0
# 264529  [[(Henry, NNP)], (hosting, VBG), (dinner, NN),...  2020.0
#
# [168330 rows x 18 columns]

# %%
def create_gender_dictionaries(df):
    # Initialize dictionaries for male and female characters
    male_dict = {}
    female_dict = {}

    # Iterate through the dataframe and populate dictionaries
    for index, row in df.iterrows():
        gender = row['actor_gender']
        decade = row['decade'] # we want the create a ductionnary per decade to later analyze

        # Check if the gender is male and handle empty lists (characters don't necessarily have words of the 3 cat. associated to them
        if gender == 'M':
            if decade not in male_dict:
                male_dict[decade] = {'Verbs': [], 'Adjectives': [], 'Nouns': []} # create a dict per decade

            male_dict[decade]['Verbs'].extend(row['Verbs']) if row['Verbs'] else None
            male_dict[decade]['Adjectives'].extend(row['Adjectives']) if row['Adjectives'] else None
            male_dict[decade]['Nouns'].extend(row['Nouns']) if row['Nouns'] else None

        # Check if the gender is female and handle empty lists
        elif gender == 'F':
            if decade not in female_dict:
                female_dict[decade] = {'Verbs': [], 'Adjectives': [], 'Nouns': []}

            female_dict[decade]['Verbs'].extend(row['Verbs']) if row['Verbs'] else None
            female_dict[decade]['Adjectives'].extend(row['Adjectives']) if row['Adjectives'] else None
            female_dict[decade]['Nouns'].extend(row['Nouns']) if row['Nouns'] else None

    return male_dict, female_dict

# %%
male_dict, female_dict = create_gender_dictionaries(final_personas_df)

# %%
#test function to check the dictionnaries per decade
def print_gender_dictionaries(male_dict, female_dict):
    # Print the first few elements of each decade in the male dictionary
    print("Male Dictionary:")
    for decade, values in male_dict.items():
        print(f"Decade: {decade}")
        print(f"Verbs: {values['Verbs'][:5]}")
        print(f"Adjectives: {values['Adjectives'][:5]}")
        print(f"Nouns: {values['Nouns'][:5]}")
        print()

    # Print the first few elements of each decade in the female dictionary
    print("Female Dictionary:")
    for decade, values in female_dict.items():
        print(f"Decade: {decade}")
        print(f"Verbs: {values['Verbs'][:5]}")
        print(f"Adjectives: {values['Adjectives'][:5]}")
        print(f"Nouns: {values['Nouns'][:5]}")
        print()

# Assuming df is your DataFrame
print_gender_dictionaries(male_dict, female_dict)
# Out:
# Male Dictionary:
# Decade: 1910.0
# Verbs: ['fellow', 'examin', 'examin', 'pawnshop', 'dust']
# Adjectives: ['burglar', 'dependable', 'assistant', 'pawnshop', 'fabulous']
# Nouns: ['competes', 'shop', 'capture', 'destroys', 'clock']
#
# Decade: 1920.0
# Verbs: ['get', 'outbreak', 'escap', 'rescu', 'end']
# Adjectives: ['rumble', 'several', 'Tong', 'timely', 'arrival']
# Nouns: ['ride', 'home', 'Buster', 'seat', 'Buster']
#
# Decade: 1930.0
# Verbs: ['tell', 'tell', 'love', 'want', 'want']
# Adjectives: ['bedtime', 'visual', 'shtick', 'next', 'whole']
# Nouns: ['Healy', 'proceeds', 'Ride', 'daughter', 'Pauline']
#
# Decade: 1940.0
# Verbs: ['meet', 'get', 'press', 'die', 'sign']
# Adjectives: ['seaman', 'vital', 'Soviet', 'port', 'second']
# Nouns: ['spends', 'time', 'wife', 'Joe', 'marries']
#
# Decade: 1950.0
# Verbs: ['tell', 'agre', 'work', 'hire', 'murder']
# Adjectives: ['Egyptian', 'general', 'general', 'mutual', 'general']
# Nouns: ['Julius', 'Caesar', 'Queen', 'Cleopatra', 'Queen']
#
# Decade: 1960.0
# Verbs: ['beast', 'lightn', 'come', 'accord', 'requir']
# Adjectives: ['keep', 'dead', 'alive', 'even', 'flesh']
# Nouns: ['night', 'storm', 'law', 'Deputy', 'Cooper']
#
# Decade: 1970.0
# Verbs: ['worri', 'hail', 'hail', 'fear', 'badger']
# Adjectives: ['worried', 'future', 'future', 'arrival', 'subsequent']
# Nouns: ['Jesus', 'popularity', 'Judas', 'popularity', 'God']
#
# Decade: 1980.0
# Verbs: ['tri', 'get', 'live', 'unemploy', 'love']
# Adjectives: ['High', 'senior', 'respective', 'social', 'wrong']
# Nouns: ['school', 'Walsh', 'girl', 'crush', 'school']
#
# Decade: 1990.0
# Verbs: ['send', 'talent', 'come', 'awaken', 'awaken']
# Adjectives: ['artificial', 'close', 'secret', 'souls', 'foul']
# Nouns: ['intelligence', 'Toulon', 'secret', 'Sutekh', 'Sutekh']
#
# Decade: 2000.0
# Verbs: ['introduc', 'charm', 'work', 'romanc', 'seduc']
# Adjectives: ['charismatic', 'charismatic', 'stylish', 'stylish', 'hedonistic']
# Nouns: ['film', 'Alfie', 'Cockney', 'Manhattan', 'lad']
#
# Decade: 2010.0
# Verbs: ['stop', 'bring', 'bring', 'neighbor', 'love']
# Adjectives: ['twentieth', 'elderly', 'successful', 'free', 'innocent']
# Nouns: ['madman', 'changes', 'history', 'century', 'actress']
#
# Decade: 2020.0
# Verbs: ['becom', 'known', 'haunt', 'roll', 'decid']
# Adjectives: ['haunted', 'former', 'spectral', 'spectral', 'investigate']
# Nouns: ['Theatre', 'buildings', 'city', 'buildings', 'city']
#
# Female Dictionary:
# Decade: 1910.0
# Verbs: ['agre', 'agre', 'marri', 'begin', 'career']
# Adjectives: ['interested', 'Next', 'girlfriend', 'several', 'pregnant']
# Nouns: ['Plump', 'Runt', 'girl', 'Elsie', 'Runt']
#
# Decade: 1920.0
# Verbs: ['develop', 'work', 'design', 'ambit', 'encourag']
# Adjectives: ['much', 'good', 'good', 'next', 'hot']
# Nouns: ['crush', 'secretary', 'MGM', 'MGM', 'cameraman']
#
# Decade: 1930.0
# Verbs: ['train', 'arriv', 'open', 'care', 'want']
# Adjectives: ['new', 'particular', 'beautiful', 'irresponsible', 'beautiful']
# Nouns: ['starts', 'Colonel', 'Dodge', 'Dodge', 'knew']
#
# Decade: 1940.0
# Verbs: ['murder', 'gone', 'twin', 'return', 'angel']
# Adjectives: ['physician', 'deep', 'dark', 'dark', 'impression']
# Nouns: ['brother', 'occult', 'sciences', 'sciences', 'arts']
#
# Decade: 1950.0
# Verbs: ['look', 'want', 'look', 'want', 'think']
# Adjectives: ['next', 'bookshop', 'first', 'famous', 'new']
# Nouns: ['magazine', 'publisher', 'editor', 'magazine', 'fashion']
#
# Decade: 1960.0
# Verbs: ['play', 'arriv', 'believ', 'believ', 'abil']
# Adjectives: ['bizarre', 'upscale', 'bizarre', 'chic', 'upscale']
# Nouns: ['propensity', 'fashion', 'case', 'case', 'socialite']
#
# Decade: 1970.0
# Verbs: ['seen', 'move', 'girlfriend', 'invit', 'invit']
# Adjectives: ['nbsp', 'girlfriend', 'dinner', 'kiss', 'sure']
# Nouns: ['Planet', 'Hall', 'informs', 'X', 'Mary']
#
# Decade: 1980.0
# Verbs: ['need', 'suffoc', 'suffoc', 'overrid', 'struggl']
# Adjectives: ['new', 'racial', 'racial', 'young', 'genuine']
# Nouns: ['school', 'kind', 'guard', 'dogs', 'coach']
#
# Decade: 1990.0
# Verbs: ['see', 'attempt', 'see', 'get', 'recal']
# Adjectives: ['busy', 'last', 'serviced', 'pimp', 'low']
# Nouns: ['money', 'attention', 'police', 'employees', 'Los']
#
# Decade: 2000.0
# Verbs: ['clerk', 'bride', 'bold', 'hold', 'hostag']
# Adjectives: ['uncomfortable', 'bold', 'speak', 'ransom', 'steal']
# Nouns: ['Buckingham', 'St', 'bank', 'clerk', 'orders']
#
# Decade: 2010.0
# Verbs: ['return', 'seem', 'play', 'play', 'schedul']
# Adjectives: ['small', 'strong', 'strong', 'young', 'gentle']
# Nouns: ['Cola', 'returns', 'Earth', 'Lucy', 'Earth']
#
# Decade: 2020.0
# Verbs: ['find', 'disguis', 'oper', 'investig', 'investig']
# Adjectives: ['reclusive', 'social', 'reclusive', 'social', 'Nublar']
# Nouns: ['college', 'student', 'media', 'fame', 'college']

# %%
for decade, categories in female_dict.items():
    # Accessing the frequency of "pregnant" in the 'Nouns' category for the current decade
    pregnant_frequency_Nouns = categories.get('Nouns', []).count('flattery')

    # Accessing the frequency of "pregnant" in the 'Verbs' category for the current decade
    pregnant_frequency_Verbs = categories.get('Verbs', []).count('flattery')

    # Accessing the frequency of "pregnant" in the 'Adjectives' category for the current decade
    pregnant_frequency_Adj = categories.get('Adjectives', []).count('flattery')

    print(f"Decade: {decade}")
    print("Frequency of 'flattery' in female_dict nouns:", pregnant_frequency_Nouns)
    print("Frequency of 'flattery' in female_dict verbs:", pregnant_frequency_Verbs)
    print("Frequency of 'flattery' in female_dict adj:", pregnant_frequency_Adj)
    print()
# Out:
# Decade: 1910.0
# Frequency of 'flattery' in female_dict nouns: 0
# Frequency of 'flattery' in female_dict verbs: 0
# Frequency of 'flattery' in female_dict adj: 0
#
# Decade: 1920.0
# Frequency of 'flattery' in female_dict nouns: 0
# Frequency of 'flattery' in female_dict verbs: 0
# Frequency of 'flattery' in female_dict adj: 0
#
# Decade: 1930.0
# Frequency of 'flattery' in female_dict nouns: 0
# Frequency of 'flattery' in female_dict verbs: 0
# Frequency of 'flattery' in female_dict adj: 0
#
# Decade: 1940.0
# Frequency of 'flattery' in female_dict nouns: 0
# Frequency of 'flattery' in female_dict verbs: 0
# Frequency of 'flattery' in female_dict adj: 0
#
# Decade: 1950.0
# Frequency of 'flattery' in female_dict nouns: 0
# Frequency of 'flattery' in female_dict verbs: 0
# Frequency of 'flattery' in female_dict adj: 0
#
# Decade: 1960.0
# Frequency of 'flattery' in female_dict nouns: 0
# Frequency of 'flattery' in female_dict verbs: 0
# Frequency of 'flattery' in female_dict adj: 0
#
# Decade: 1970.0
# Frequency of 'flattery' in female_dict nouns: 0
# Frequency of 'flattery' in female_dict verbs: 0
# Frequency of 'flattery' in female_dict adj: 0
#
# Decade: 1980.0
# Frequency of 'flattery' in female_dict nouns: 0
# Frequency of 'flattery' in female_dict verbs: 0
# Frequency of 'flattery' in female_dict adj: 0
#
# Decade: 1990.0
# Frequency of 'flattery' in female_dict nouns: 3
# Frequency of 'flattery' in female_dict verbs: 0
# Frequency of 'flattery' in female_dict adj: 1
#
# Decade: 2000.0
# Frequency of 'flattery' in female_dict nouns: 0
# Frequency of 'flattery' in female_dict verbs: 0
# Frequency of 'flattery' in female_dict adj: 0
#
# Decade: 2010.0
# Frequency of 'flattery' in female_dict nouns: 0
# Frequency of 'flattery' in female_dict verbs: 0
# Frequency of 'flattery' in female_dict adj: 0
#
# Decade: 2020.0
# Frequency of 'flattery' in female_dict nouns: 3
# Frequency of 'flattery' in female_dict verbs: 0
# Frequency of 'flattery' in female_dict adj: 0

# %%
def calculate_word_frequencies(dictionary):
    # Initialize a dictionary for each category (Verbs, Adjectives, Nouns)
    frequencies = {'Verbs': {}, 'Adjectives': {}, 'Nouns': {}}

    # Iterate through the dictionary and calculate word frequencies
    for category, words in dictionary.items():
        total_words = len(words)
        word_counter = Counter(words)
        frequencies[category] = {word: count / total_words for word, count in word_counter.items()}

    return frequencies

# %%
male_frequencies_per_decade  = {decade: calculate_word_frequencies(dictionary) for decade, dictionary in male_dict.items()}
female_frequencies_per_decade = {decade: calculate_word_frequencies(dictionary) for decade, dictionary in female_dict.items()}

# %%
def subtract_frequencies(frequencies_1, frequencies_2): # function to get relative frequencies for a word in 2 separate dictionnaries
    subtracted_frequencies = {}
    words_only_in_freq1 = set()
    words_only_in_freq2 = set()

    # Iterate through decades
    for decade in frequencies_1.keys():
        # Initialize dictionary for the current decade
        subtracted_frequencies[decade] = {'Verbs': {}, 'Adjectives': {}, 'Nouns': {}}

        # Iterate through categories (Verbs, Adjectives, Nouns)
        for category in frequencies_1[decade].keys():
            # Get the set of words in both dictionaries for the current category
            common_words = set(frequencies_1[decade][category].keys()) & set(frequencies_2[decade][category].keys())
            # Calculate the subtracted frequencies for the current category
            for word in common_words:
                freq_1 = frequencies_1[decade][category].get(word, 0)
                freq_2 = frequencies_2[decade][category].get(word, 0)
                subtracted_frequencies[decade][category][word] = freq_1 - freq_2

            # Add the remaining words (present in one dictionary but not the other) with a frequency of 0
            remaining_words_1 = set(frequencies_1[decade][category].keys()) - common_words # words only in freq_1
            remaining_words_2 = set(frequencies_2[decade][category].keys()) - common_words # words only in freq_2
            #print(remaining_words_2)

            words_only_in_freq1.update(remaining_words_1)
            words_only_in_freq2.update(remaining_words_2)

            for word in remaining_words_1:
                subtracted_frequencies[decade][category][word] = frequencies_1[decade][category][word] # assign the freq of freq_1 to that word

            for word in remaining_words_2:

                subtracted_frequencies[decade][category][word] = -frequencies_2[decade][category][word]

    return subtracted_frequencies, words_only_in_freq1, words_only_in_freq2

# %%
relative_frequencies, unique_male, unique_female = subtract_frequencies(male_frequencies_per_decade, female_frequencies_per_decade)

# %% [markdown]
# do relative freq : male - female
# prendre en valeur abs les top 10 et les plot (-1,1)
# si le mot existe pas dans l'autre dict, then freq = 0
# prendre top 10 femmes et top 10 hommes
# voir pour décider un threshold if needed (si freq diff vraiment vraiment minime)

# %%
def plot_top_words_per_decade(relative_frequencies, categories):
    # Create subplots for each category
    decades = relative_frequencies.keys()
    num_categories = len(categories)

    fig, axs = plt.subplots(len(decades), num_categories, figsize=(5 * num_categories, 3 * len(decades)))

    # Iterate through each decade
    for i, decade in enumerate(decades):
        for j, category in enumerate(categories):
            # Get the top words and their frequencies
            top_words_positive = [word for _, word in sorted(
                zip(relative_frequencies[decade][category].values(), relative_frequencies[decade][category].keys()),
                key=lambda x: x[0],
                reverse=True
            )[:5]]

            top_words_negative = [word for _, word in sorted(
                zip(relative_frequencies[decade][category].values(), relative_frequencies[decade][category].keys()),
                key=lambda x: x[0]
            )[:5]]

            top_words = top_words_positive + top_words_negative
            top_frequencies = [relative_frequencies[decade][category][word] for word in top_words]

            # Plot the bar chart for each category
            bars = axs[i, j].bar(top_words, top_frequencies, color=['skyblue' if freq >= 0 else 'pink' for freq in top_frequencies])
            axs[i, j].set_title(f'{category} {decade}')
            axs[i, j].set_ylabel('Frequency Difference (male - female)')

            # Rotate x-axis tick labels
            axs[i, j].set_xticklabels(top_words, rotation=45, ha='right')

    # Adjust layout and show the plots
    plt.tight_layout()
    plt.show()

# %%
categories_to_plot = ['Verbs', 'Adjectives', 'Nouns']
plot_top_words_per_decade(relative_frequencies, categories_to_plot)
# Out:
# /var/folders/my/4hvdfxj10f94l0xh5rd30q_h0000gn/T/ipykernel_46896/1212633334.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i, j].set_xticklabels(top_words, rotation=45, ha='right')

# %% [markdown]
# ## to do list:
# - stemming on verbs
# - display words associated to unisex per decade (with top frequencies)

# %%
print("Words only in frequencies_dict1:", unique_male)
# Out:
# Words only in frequencies_dict1: {'Therefore', 'Remington', 'surname', 'sworn', 'lulls', 'Newfoundland', 'thornton', 'dallianc', 'Repulsa', 'wraparound', 'bboy', 'séance', 'whizzes', 'retiree', 'holsters', 'Ziko', 'ruthlessli', 'amiable', 'divergent', 'decadent', 'Tutsis', 'settlet', 'ointment', 'timelessness', 'platonic', 'superspe', 'Embraceable', 'tastin', 'nerdi', 'sedate', 'LaFlam', 'idT24DAAAAIBAJ', 'Salerno', 'complicates', 'Mallory', 'Afghist', 'avoid', 'Fats', 'solution', 'P', 'Really', 'Spelling', 'Dudevant', 'intim', 'Kashaubayev', 'Haveland', 'Mat', 'tea', 'mincemeat', 'Starbuck', 'attributes', 'rupt', 'Sleerik', 'template', 'insignific', 'Inevitably', 'sql84771', 'Scot', 'Duvane', 'clim', 'teleporter', 'weatherman', 'Poodle', 'ADIEU', 'weaponri', 'effectiveness', 'dave', 'RITES', 'Drummer', 'tundra', 'Butts', 'anthropophobic', 'demoralize', 'dined', 'Cypher', 'medley', 'supervised', 'Missiles', 'tars', 'proscenium', 'Blyth', 'ravaging', 'loathe', 'Goin', 'Repairman', 'impressionable', 'garag', 'Trunkman', 'Raus', 'Brisco', 'sowed', 'Contents', 'Trouzdale', 'harp', 'Brite', 'Lopaki', 'Lachance', 'Brandau', 'Poll', 'Sheffner', 'Carnaval', 'Crille', 'kegs', 'awestruck', 'delinquency', 'Guillermo', 'Pollack', 'Louia', 'Pandit', 'bail', 'Ricci', 'astray', 'Halpern', 'ignoble', 'Brith', 'shortcuts', 'allegiances', 'Lieutenants', 'McCreary', 'broods', 'fifti', 'Devil', 'ceas', 'mic', 'Hoovers', 'infraction', 'Newborn', 'miami', 'Repeating', 'ButterCream', 'Grafton', 'agamemnon', 'TIME', 'Replay', 'Dibble', 'blazes', 'Fortnight', 'Booger', 'charters', 'dragging', 'submersible', 'cheeks', 'maximize', 'racing', 'incremental', 'Templars', 'glands', 'hundred', 'howing', 'Graysons', 'Harsh', 'Erector', 'Eldridge', 'defund', 'WRB', 'planets', 'flagging', 'Lenders', 'glues', 'coolies', 'Scalawag', 'Vehicle', 'Edd', 'outw', 'sorry', 'offstag', 'Geri', 'mores', 'Heguy', 'hundr', 'catalog', 'standalone', 'flat', 'reading', 'Oaf', 'Skolnick', 'hurts', 'Flightplan', 'SDF', 'ason', 'Spade', 'Benz', 'Citing', 'Outer', 'chi', 'quizzes', 'Williamsen', 'packag', 'Sash', 'expand', 'Galveston', 'crystallized', 'Sharkey', 'Appealing', 'Rum', 'Blustery', 'jibes', 'Venarius', 'Edwin', 'sorter', 'Hechy', 'steamy', 'Miyamoto', 'Bux', 'afir', 'unsurpass', 'dignifies', 'aroused', 'recast', 'realizes', 'appal', 'forest', 'aviat', 'melodramatic', 'Castiglione', 'demeurons', 'Huisman', 'Guinean', 'belies', 'Mapplethorpe', 'recital', 'obliviou', 'emce', 'dysentery', 'Brighton', 'Ertel', 'obstinacy', 'booby', 'dojo', 'labcoat', 'F4', 'Setec', 'buffer', 'Famed', 'Lowenthal', 'Stromboli', 'Solution', 'Guerilla', 'Abnerish', 'thaw', 'serenity', 'swerv', 'regretting', 'godspe', 'Patrone', 'barbarity', 'Balicki', 'Tascosa', 'makg', 'Mistaking', 'Strausman', 'scarab', 'Quartet', 'Declining', 'LaMarre', 'Twillinger', 'Amassing', 'watchman', 'rollerskate', 'Lucero', 'Jookiba', 'Cop', 'Paleolithic', 'decoder', 'trips', 'Lagrand', 'squawk', 'vapid', 'geode', 'Chariot', 'Grandpere', 'extension', 'Mayor', 'Leo', 'atelier', 'GearEntertainment', 'skirmishers', 'Mudge', 'Quibyq', 'Standoff', 'Providing', 'motel', 'Armitage', 'Poor', 'Warnowski', 'Guglielmo', 'Gospel', 'wrongs', 'unkillable', 'Oreste', 'Pardella', 'sporting', 'cruhe', 'Snob', 'largeness', 'darker', 'vagueness', 'stayg', 'saucepans', 'Einsatzkommandos', 'Brehmer', 'sneering', 'Trabbi', 'treak', 'Scumbag', 'instruct', 'summond', 'groupie', 'astut', 'Monday', 'arouse', 'amg', 'Minas', 'rattl', 'mitts', 'Gilson', 'tortilla', 'gunplay', 'canceling', 'hallucination', 'wrests', 'veritable', 'lped', 'assasss', 'Hylton', 'retribution', 'orthopedic', 'unintentional', 'gull', 'Emile', 'Sandin', 'relieved', 'Spartans', 'Spaceman', 'landmines', 'supervisor', 'bonk', 'Asmodeus', 'scruffy', 'winstead', 'gyrations', 'bigots', 'Bourdelle', 'appnt', 'festering', 'prune', 'object', 'crummy', 'Wary', 'committees', 'Incidentally', 'splinter', 'genocidal', 'frican', 'lecher', 'McClosky', 'CONNECTION', 'conscienc', 'Square' ...

# %%
print("Words only in frequencies_dict2:", unique_female)
# Out:
# Words only in frequencies_dict2: {'Remington', 'Therefore', 'sworn', 'surname', 'wryli', 'needed', 'Newfoundland', 'unscrews', 'disintegrated', 'dallianc', 'wraparound', 'goofiest', 'séance', 'trickl', 'Henny', 'retiree', 'Alden', 'Bolsheviks', 'falsetto', 'harbour', 'improve', 'divergent', 'decadent', 'platonic', 'Moments', 'nerdi', 'Salerno', 'complicates', 'nameKurtwood', 'local', 'erected', 'avoid', 'threatening', 'sics', 'solution', 'blowtorch', 'clubs', 'indoors', 'intim', 'inarticul', 'brigantine', 'tea', 'spotlight', 'attributes', 'contracting', 'Intercut', 'banking', 'pajamas', 'Hensen', 'Hix', 'schoolwork', 'homegrown', 'Connelly', 'famers', 'trolley', 'prowler', 'hesitant', 'Stricken', 'landfall', 'effectiveness', 'dave', 'Correcting', 'churchyard', 'medley', 'supervised', 'initi', 'farming', 'Niotes', 'tars', 'concerning', 'Blyth', 'hawaii', 'Cisely', 'parodi', 'Tope', 'Delancey', 'impressionable', 'Waterhouse', 'frolic', 'Pidgeot', 'harp', 'Brite', 'generous', 'architecture', 'Benita', 'rebuild', 'poisoned', 'Legler', 'awestruck', 'Safari', 'Revill', 'attained', 'sociological', 'rd', 'Mukes', 'astray', 'creak', 'Tula', 'knuckl', 'Dozens', 'hower', 'Margaret', 'Organizing', 'broods', 'fifti', 'mic', 'Newborn', 'McClary', 'Phibes', 'mm', 'scarlet', 'TIME', 'Marathon', 'dragging', 'escapades', 'Thurlow', 'matchmaking', 'racing', 'telekinesi', 'Crow', 'noting', 'Jacopus', 'hundred', 'Templars', 'tires', 'Shari', 'stubborn', 'Trion', 'boxes', 'defund', 'breakneck', 'marian', 'thr', 'flagging', 'chilly', 'Rigby', 'upswing', 'Locust', 'Sheffield', 'rBitter', 'wile', 'Medved', 'Geri', 'mores', 'bombard', 'Kovach', 'flat', 'reading', 'ADD', 'revs', 'woodrow', 'Edmonton', 'emoticon', 'Ginny', 'alcalde', 'humanity', 'chi', 'Beltravers', 'quizzes', 'pullg', 'freshen', 'expand', 'Purge', 'IRL', 'Velva', 'Melkinen', 'Albino', 'Macy', 'Station', 'wheatgrass', 'Aa', 'Norval', 'qualified', 'dyname', 'Edwin', 'sorter', 'steamy', 'Lawton', 'Miyamoto', 'preserved', 'clean', 'aroused', 'forest', 'melodramatic', 'timeframe', 'belies', 'teetotallers', 'maidservant', 'amplitud', 'MESSIAH', 'drugging', 'booby', 'Tanguay', 'Audible', 'labcoat', 'unadulter', 'kitties', 'Cas', 'bustling', 'glimmers', 'Betki', 'buffer', 'misdeal', 'Cuch', 'becam', 'thaw', 'serenity', 'blo', 'swerv', 'recap', 'terroristic', 'regretting', 'statistic', 'assets', 'Exhilarated', 'Golban', 'footman', 'Nolee', 'Mistaking', 'Drea', 'Vindictive', 'scarab', 'MEET', 'Hao', 'Valle', 'funding', 'Pear', 'erial', 'Majorca', 'Chrtie', 'watchman', 'Cravalho', 'phosphorescent', 'pornographi', 'strube', 'preachy', 'GeeklyChic', 'trips', 'Neesden', 'Annabeth', 'stles', 'vapid', 'ash', 'squawk', 'pandering', 'apolitical', 'Cinderella', 'stacks', 'pat', 'extension', 'Maranov', 'Mudge', 'conform', 'apprehending', 'Danceteria', 'motel', 'Poor', 'STONE', 'Cute', 'kata', 'FEVER', 'squander', 'boycott', 'boring', 'unveils', 'bland', 'effici', 'largeness', 'Gubec', 'snout', 'stayg', 'Astro', 'coaxed', 'Disoriented', 'Daughter', 'encag', 'georg', 'whilst', 'treak', 'groupie', 'bucki', 'ooooz', 'teby', 'Umutoni', 'snafu', 'reinforcements', 'prosecutes', 'Crispin', 'tortilla', 'coeds', 'Argenziano', 'halo', 'Solely', 'depressingly', 'lped', 'acrimony', 'femoral', 'looms', 'retribution', 'stroll', 'chihuahua', 'Emile', 'relieved', 'insult', 'Royce', 'supervisor', 'bonk', 'scruffy', 'bigots', 'kinship', 'chugs', 'cannons', 'festering', 'prune', 'Thieriot', 'Milick', 'crummy', 'stylistic', 'Gilman', 'herbal', 'Challenge', 'hidebound', 'pods', 'Check', 'lunch', 'abject', 'conscienc', 'Bursting', 'futility', 'plummet', 'operant', 'detection', 'intoxication', 'unconnect', 'drunks', 'robust', 'hangs', 'dischargment', 'Rubinsky', 'Mathilda', 'Vestron', 'Perrault', 'despair', 'annexed', 'upmarket', 'licks', 'animation', 'wd', 'argut', 'showmanship', 'rotate', 'superficial', 'dovey', 'Silent', 'proviso', 'spindle', 'Dearborn', 'dreami', 'thirteenth', 'suitcases', 'overcautious', 'nameA', 'medival',  ...

# %% [markdown]
# sets are empty so there is no words that appear only in one gender and not the other. Very weird and unexpected.

# %% [markdown]
# # TO DO
# heck words that are only on one or the other dictionary with high freq

# %% [markdown]
# check if the words associated to each gender are statistically significantly different. For that we can use the Chi-squared test. Our null hypothesis (H0) is that there is no significant difference in the distribution of words associated with male and female characters.While the alternative hypothesis (HA)s that there is a significant difference in the distribution of words associated with male and female characters.

# %%
import scipy.stats as stats

subtract_frequencies(male_frequencies_per_decade, female_frequencies_per_decade)

for decade in set(df['decade']):
    decade_df = df[df['decade'] == decade]

    # Create gender dictionaries for the current decade
    male_dict_decade, female_dict_decade = create_gender_dictionaries(decade_df)

    # Calculate word frequencies for the current decade
    male_frequencies_decade = calculate_word_frequencies(male_dict_decade)
    female_frequencies_decade = calculate_word_frequencies(female_dict_decade)

    # Calculate and print chi-square for each category
    for category in ["Verbs", "Adjectives", "Nouns"]:
        chi2_stat, p_val = stats.chisquare(f_obs=male_frequencies_decade[category].values(), f_exp=female_frequencies_decade[category].values())
        print(f'{category} in {decade}: Chi2 Stat = {chi2_stat}, p-value = {p_val}')
# Out:
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 5
#       1 import scipy.stats as stats
#       3 subtract_frequencies(male_frequencies_per_decade, female_frequencies_per_decade)
# ----> 5 for decade in set(df['decade']):
#       6     decade_df = df[df['decade'] == decade]
#       8     # Create gender dictionaries for the current decade
#
# NameError: name 'df' is not defined

# %%
common_keys = set(male_dict[1950]['Verbs'].keys()) & set(female_dict[1950]['Verbs'].keys())

# Create subsets by filtering based on common keys
male_subset = {key: male_dict[1950]['Verbs'].keys() for key in common_keys}
female_subset = {key: female_dict[1950]['Verbs'].keys() for key in common_keys}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 common_keys = set(male_dict[1950]['Verbs'].keys()) & set(female_dict[1950]['Verbs'].keys())
#       3 # Create subsets by filtering based on common keys
#       4 male_subset = {key: male_dict[1950]['Verbs'].keys() for key in common_keys}
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
male_dict[1950]['Verbs']
# Out:
# ['tell',
#  'agre',
#  'work',
#  'hire',
#  'murder',
#  'reach',
#  'like',
#  'make',
#  'mistak',
#  'take',
#  'begin',
#  'agre',
#  'return',
#  'agre',
#  'return',
#  'work',
#  'daughter',
#  'mistaken',
#  'take',
#  'like',
#  'tell',
#  'take',
#  'remot',
#  'order',
#  'know',
#  'collect',
#  'take',
#  'goe',
#  'thought',
#  'ringlead',
#  'keep',
#  'suggest',
#  'shoot',
#  'turn',
#  'return',
#  'gambl',
#  'fire',
#  'forc',
#  'kill',
#  'begin',
#  'tell',
#  'come',
#  'shove',
#  'chicken',
#  'discov',
#  'lead',
#  'sleep',
#  'move',
#  'lead',
#  'sleep',
#  'move',
#  'run',
#  'see',
#  'implic',
#  'frame',
#  'allow',
#  'chicken',
#  'made',
#  'see',
#  'destroy',
#  'see',
#  'make',
#  'lead',
#  'think',
#  'gone',
#  'think',
#  'begin',
#  'den',
#  'swallow',
#  'head',
#  'stop',
#  'serv',
#  'cut',
#  'intercept',
#  'discov',
#  'ask',
#  'jerri',
#  'get',
#  'kill',
#  'lost',
#  'restrain',
#  'made',
#  'meet',
#  'meet',
#  'marri',
#  'realiz',
#  'becom',
#  'photograph',
#  'hide',
#  'continu',
#  'exposé',
#  'short',
#  'tri',
#  'guard',
#  'guard',
#  'episod',
#  'make',
#  'attempt',
#  'attempt',
#  'carri',
#  'push',
#  'place',
#  'go',
#  'get',
#  'grab',
#  'sneak',
#  'surround',
#  'smoke',
#  'stick',
#  'carri',
#  'fish',
#  'fish',
#  'cast',
#  'rod',
#  'snag',
#  'attempt',
#  'reach',
#  'tunnel',
#  'appear',
#  'appear',
#  'strap',
#  'pull',
#  'take',
#  'follow',
#  'stand',
#  'begin',
#  'punch',
#  'take',
#  'goe',
#  'execut',
#  'execut',
#  'retriev',
#  'contain',
#  'join',
#  'join',
#  'aris',
#  'take',
#  'coffin',
#  'name',
#  'caught',
#  'caught',
#  'caught',
#  'carri',
#  'carri',
#  'anim',
#  'rescu',
#  'releas',
#  'credit',
#  'get',
#  'grow',
#  'told',
#  'concoct',
#  'involv',
#  'meet',
#  'crusti',
#  'come',
#  'come',
#  'episod',
#  'outright',
#  'reason',
#  'becom',
#  'lead',
#  'play',
#  'subdu',
#  'involv',
#  'show',
#  'come',
#  'come',
#  'becom',
#  'becom',
#  'work',
#  'plain',
#  'daughter',
#  'stop',
#  'murder',
#  'murder',
#  'ransom',
#  'rob',
#  'like',
#  'make',
#  'friend',
#  'take',
#  'demand',
#  'return',
#  'disgust',
#  'want',
#  'keep',
#  'suggest',
#  'turn',
#  'return',
#  'play',
#  'subdu',
#  'subdu',
#  'receiv',
#  'episod',
#  'show',
#  'show',
#  'come',
#  'becom',
#  'includ',
#  'turn',
#  'tell',
#  'secret',
#  'exchang',
#  'keep',
#  'harbor',
#  'stirl',
#  'caught',
#  'caught',
#  'speak',
#  'speak',
#  'enforc',
#  'befriend',
#  'trap',
#  'sleep',
#  'trap',
#  'sleep',
#  'pursu',
#  'fli',
#  'fli',
#  'tri',
#  'depart',
#  'run',
#  'laugh',
#  'run',
#  'give',
#  'say',
#  'continu',
#  'continu',
#  'act',
#  'jump',
#  'catch',
#  'run',
#  'cri',
#  'find',
#  'quot',
#  'quot',
#  'perform',
#  'suggest',
#  'cast',
#  'suggest',
#  'cast',
#  'insist',
#  'live',
#  'insist',
#  'age',
#  'base',
#  'make',
#  'base',
#  'assum',
#  'critic',
#  'end',
#  'face',
#  'demand',
#  'includ',
#  'believ',
#  'learn',
#  'love',
#  'succe',
#  'open',
#  'believ',
#  'announc',
#  'kill',
#  'act',
#  'suppos',
#  'betray',
#  'lead',
#  'take',
#  'hear',
#  'beaten',
#  'grab',
#  'start',
#  'say',
#  'restrain',
#  'beat',
#  'beat',
#  'sent',
#  'made',
#  'made',
#  'act',
#  'act',
#  'suspect',
#  'reveal',
#  'betray',
#  'lead',
#  'beaten',
#  'grab',
#  'thug',
#  'start',
#  'becom',
#  'lost',
#  'control',
#  'lost',
#  'say',
#  'garbag',
#  'sent',
#  'brought',
#  'made',
#  'train',
#  'fall',
#  'fall',
#  'develop',
#  'sing',
#  'invit',
#  'becom',
#  'hospit',
#  'decid',
#  'mistak',
#  'wheel',
#  'wed',
#  'arrest',
#  'kill',
#  'arrest',
#  'take',
#  'take',
#  'yell',
#  'becom',
#  'sent',
#  'given',
#  'given',
#  'known',
#  'known',
#  'walk',
#  'known',
#  'walk',
#  'show',
#  'skill',
#  'take',
#  'rescu',
#  'struck',
#  'rescu',
#  'ask',
#  'pay',
#  'rescu',
#  'join',
#  'band',
#  'make',
#  'obtain',
#  'help',
#  'escap',
#  'send',
#  'threaten',
#  'releas',
#  'releas',
#  'learn',
#  'learn',
#  'taken',
#  'give',
#  'save',
#  'plan',
#  'warn',
#  'hide',
#  'hide',
#  'get',
#  'pose',
#  'provid',
#  'remov',
#  'ensu',
#  'warn',
#  'gone',
#  'gone',
#  'leav',
#  'persuad',
#  'kill',
#  'find',
#  'find',
#  'kill',
#  'hold',
#  'find',
#  'find',
#  'aim',
#  'free',
#  'embrac',
#  'embrac',
#  'known',
#  'walk',
#  'show',
#  'skill',
#  'skill',
#  'shoot',
#  'take',
#  'rescu',
#  'allow',
#  'recaptur',
#  'ask',
#  'ask',
#  'reject',
#  'reject',
#  'pay',
#  'arrest',
#  'pay',
#  'rescu',
#  'rescu',
#  'band',
#  'make',
#  'make',
#  'maid',
#  'escap',
#  'escap',
#  'escap',
#  'send',
#  'offer',
#  'send',
#  'offer',
#  'releas',
#  'releas',
#  'releas',
#  'villag',
#  'learn',
#  'give',
#  'save',
#  'prison',
#  'includ',
#  'includ',
#  'rebel',
#  'agre',
#  'find',
#  'warn',
#  'hide',
#  'get',
#  'warn',
#  'gone',
#  'gone',
#  'gone',
#  'leav',
#  'leav',
#  'leav',
#  'fight',
#  'persuad',
#  'persuad',
#  'tri',
#  'persuad',
#  'persuad',
#  'stand',
#  'kill',
#  'stand',
#  'kill',
#  'refus',
#  'kill',
#  'find',
#  'hold',
#  'find',
#  'find',
#  'aim',
#  'embrac',
#  'give',
#  'get',
#  'see',
#  'head',
#  'run',
#  'bash',
#  'want',
#  'look',
#  'neighborhood',
#  'name',
#  'locat',
#  'name',
#  'run',
#  'use',
#  'give',
#  'shut',
#  'attend',
#  'lectur',
#  'lectur',
#  'lectur',
#  'get',
#  'pretend',
#  'want',
#  'shop',
#  'arriv',
#  'shop',
#  'arriv',
#  'treat',
#  'make',
#  'pull',
#  'attempt',
#  'cut',
#  'get',
#  'convinc',
#  'convinc',
#  'develop',
#  'fall',
#  'love',
#  'learn',
#  'give',
#  'learn',
#  'give',
#  'give',
#  'goe',
#  'talk',
#  'goe',
#  'scheme',
#  'make',
#  'confront',
#  'confront',
#  'lead',
#  'lead',
#  'caus',
#  'leav',
#  'leav',
#  'make',
#  'run',
#  'leav',
#  'get',
#  'wed',
#  'plane',
#  'suppos',
#  'run',
#  'suppos',
#  'take',
#  'run',
#  'run',
#  'learn',
#  'bash',
#  'announc',
#  'kill',
#  'announc',
#  'kill',
#  'betray',
#  'lead',
#  'discov',
#  'beaten',
#  'grab',
#  'sent',
#  'given',
#  'explain',
#  'explain',
#  'bloodstain',
#  'agre',
#  'go',
#  'obtain',
#  'gone',
#  'maid',
#  'want',
#  'own',
#  'frame',
#  'reject',
#  'pretend',
#  'take',
#  'replac',
#  'replac',
#  'replac',
#  'tri',
#  'go',
#  'left',
#  'surround',
#  'continu',
#  'perform',
#  'visit',
#  'want',
#  'help',
#  'escap',
#  'wilfr',
#  'go',
#  'go',
#  'decepti',
#  'go',
#  'manag',
#  'buy',
#  'stain',
#  'close',
#  'even',
#  'admit',
#  'make',
#  'murder',
#  'blame',
#  'see',
#  'brought',
#  'fall',
#  'enabl',
#  'get',
#  'get',
#  'kill',
#  'got',
#  'make',
#  'escap',
#  'follow',
#  'decapit',
#  'get',
#  'lead',
#  'scream',
#  'lost',
#  'say',
#  'restrain',
#  'beat',
#  'suppos',
#  'suspect',
#  'end',
#  'train',
#  'fall',
#  'fall',
#  'develop',
#  'die',
#  'decid',
#  'brought',
#  'psychiatrist',
#  'age',
#  'critic',
#  'end',
#  'hit',
#  'realiz',
#  'given',
#  'believ',
#  'think',
#  'hear',
#  'cast',
#  'cast',
#  'suppos',
#  'tell',
#  'come',
#  'dress',
#  'saw',
#  'respond',
#  'tell',
#  'suppos',
#  'tell',
#  'suppos',
#  'climb',
#  'chase',
#  'follow',
#  'corner',
#  'gun',
#  'pull',
#  'wonder',
#  'set',
#  'gun',
#  'direct',
#  'want',
#  'want',
#  'think',
#  'take',
#  'lectur',
#  'get',
#  'tri',
#  'make',
#  'attempt',
#  'work',
#  'work',
#  'develop',
#  'forget',
#  'find',
#  'get',
#  'scheme',
#  'make',
#  'lead',
#  'caus',
#  'urg',
#  'show',
#  'get',
#  'made',
#  'leav',
#  'made',
#  'plane',
#  'suppos',
#  'take',
#  'run',
#  'bash',
#  'realiz',
#  'find',
#  'known',
#  'cover',
#  'brother',
#  'star',
#  'star',
#  'show',
#  'impoverish',
#  'connect',
#  'fall',
#  'love',
#  'dancer',
#  'assist',
#  'ask',
#  'suppos',
#  'wed',
#  'prove',
#  'engag',
#  'speed',
#  'glow',
#  'desert',
#  'caus',
#  'object',
#  'escap',
#  'terrifi',
#  'run',
#  'philand',
#  'pretend',
#  'leav',
#  'make',
#  'fli',
#  'pistol',
#  'eg',
#  'orb',
#  'wreck',
#  'fli',
#  'roof',
#  'get',
#  'roof',
#  'get',
#  'kill',
#  'begin',
#  'kill',
#  'begin',
#  'shoot',
#  'riot',
#  'kill',
#  'find',
#  'find',
#  'lie',
#  'follow',
#  'earn',
#  'earn',
#  'prove',
#  'spot',
#  'spot',
#  'work',
#  'work',
#  'chase',
#  'chase',
#  'hurt',
#  'retriev',
#  'stalk',
#  'stalk',
#  'make',
#  'anticip',
#  'make',
#  'anticip',
#  'determin',
#  'determin',
#  'shown',
#  'leav',
#  'shown',
#  'leav',
#  'leav',
#  'make',
#  'enjoy',
#  'even',
#  'babi',
#  'open',
#  'prepar',
#  'take',
#  'bottl',
#  'take',
#  'babysit',
#  'rememb',
#  'stick',
#  'follow',
#  'firebal',
#  'speed',
#  'glow',
#  'desert',
#  'caus',
#  'get',
#  'object',
#  'reach',
#  'terrifi',
#  'run',
#  'believ',
#  'known',
#  'philand',
#  'leav',
#  'find',
#  'fire',
#  'pistol',
#  'eg',
#  'eg',
#  'call',
#  'wait',
#  'sheriff',
#  'find',
#  'orb',
#  'wreck',
#  'fli',
#  'roof',
#  'get',
#  'roof',
#  'get',
#  'kill',
#  'begin',
#  'kill',
#  'begin',
#  'shoot',
#  'riot',
#  'caus',
#  'kill',
#  'find',
#  'find',
#  'lie',
#  'firebal',
#  'red',
#  'calcul',
#  'speed',
#  'glow',
#  'speed',
#  'glow',
#  'caus',
#  'get',
#  'object',
#  'reach',
#  'terrifi',
#  'run',
#  'run',
#  'believ',
#  'believ',
#  'known',
#  'believ',
#  'known',
#  'philand',
#  'pretend',
#  'hope',
#  'pretend',
#  'make',
#  'fli',
#  'find',
#  'fire',
#  'found',
#  'eg',
#  'call',
#  'call',
#  'keep',
#  'keep',
#  'morphin',
#  'find',
#  'orb',
#  'appear',
#  'wreck',
#  'fli',
#  'wreck',
#  'fli',
#  'determin',
#  'rip',
#  'roof',
#  'get',
#  'get',
#  'drop',
#  'kill',
#  'begin',
#  'riot',
#  'kill',
#  'find',
#  'episod',
#  'episod',
#  'teach',
#  'contain',
#  'challeng',
#  'brought',
#  'brought',
#  'dislik',
#  'distress',
#  'fall',
#  'love',
#  'deal',
#  'highlight',
#  'conduct',
#  'hire',
#  'work',
#  'ask',
#  'leav',
#  'call',
#  'call',
#  'hear',
#  'hear',
#  'start',
#  'tri',
#  'tri',
#  'tri',
#  'defend',
#  'defend',
#  'use',
#  'defend',
#  'defend',
#  'heal',
#  'discov',
#  'refus',
#  'alleg',
#  'gone',
#  'hide',
#  'woke',
#  'lie',
#  'lie',
#  'examin',
#  'believ',
#  'kept',
#  'becam',
#  'devot',
#  'told',
#  'conclud',
#  'conclud',
#  'hear',
#  'walk',
#  'hear',
#  'walk',
#  'display',
#  'admit',
#  'oper',
#  'calm',
#  'tell',
#  'oper',
#  'tell',
#  'becom',
#  'embarrass',
#  'upset',
#  'embarrass',
#  'forc',
#  'hide',
#  'shoot',
#  'becom',
#  'admit',
#  'marri',
#  'come',
#  'suggest',
#  'suggest',
#  'pregnant',
#  'love',
#  'schedul',
#  'end',
#  'watch',
#  'witch',
#  'attack',
#  'charact',
#  'play',
#  'reveal',
#  'dislik',
#  'dislik',
#  'hire',
#  'react',
#  'tri',
#  'hear',
#  'open',
#  'undeclar',
#  'tri',
#  'murder',
#  'hide',
#  'lie',
#  'walk',
#  'walk',
#  'discredit',
#  'forc',
#  'find',
#  'stingi',
#  'becom',
#  'mask',
#  'banish',
#  'sit',
#  'watch',
#  'paint',
#  'resembl',
#  'miss',
#  'take',
#  'tail',
#  'leap',
#  'slip',
#  'rescu',
#  'decid',
#  'fear',
#  'take',
#  'love',
#  'run',
#  'bell',
#  'halt',
#  'imagin',
#  'spot',
#  'find',
#  'realiz',
#  'realiz',
#  'wear',
#  'reveal',
#  'want',
#  'want',
#  'admit',
#  'bell',
#  'deceit',
#  'conquer',
#  'pose',
#  'plead',
#  'embrac',
#  'emerg',
#  'startl',
#  'brought',
#  'leav',
#  'understand',
#  'tri',
#  'discov',
#  'tri',
#  'call',
#  'start',
#  'open',
#  'undeclar',
#  'trust',
#  'describ',
#  'forc',
#  'leav',
#  'maid',
#  'refus',
#  'explain',
#  'refus',
#  'explain',
#  'serv',
#  'explain',
#  'serv',
#  'serv',
#  ...]

# %%
def calculate_word_counts(dictionary):
    # Initialize a dictionary for each category (Verbs, Adjectives, Nouns)
    counts = {'Verbs': {}, 'Adjectives': {}, 'Nouns': {}}

    # Iterate through the dictionary and calculate word frequencies
    for category, words in dictionary.items():
        word_counter = Counter(words)
        counts[category] = {word: count for word, count in word_counter.items()}

    return counts

# %%
male_counts_per_decade  = {decade: calculate_word_counts(dictionary) for decade, dictionary in male_dict.items()}
female_counts_per_decade = {decade: calculate_word_counts(dictionary) for decade, dictionary in female_dict.items()}

# %%
common_keys = set(male_counts_per_decade[1950]['Verbs'].keys()) & set(female_counts_per_decade[1950]['Verbs'].keys())

# Create subsets by filtering based on common keys
male_subset = {key: male_counts_per_decade[1950]['Verbs'].keys() for key in common_keys}
female_subset = {key: female_counts_per_decade[1950]['Verbs'].keys() for key in common_keys}

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Assuming you have dictionaries like these
male_subset = {'eat': 30, 'jump': 15, 'run': 20, 'talk': 25}
female_subset = {'jump': 18, 'read': 28, 'swim': 12, 'talk': 20}

# Combine the keys from both dictionaries
all_keys = sorted(set(male_subset) | set(female_subset))

# Create arrays for male and female values in sorted order
male_values = np.array([male_subset.get(key, 0) for key in all_keys])
female_values = np.array([female_subset.get(key, 0) for key in all_keys])

# Create a contingency table for the chi-squared test
contingency_table = np.array([male_values, female_values])

# Transpose the contingency table
contingency_table = contingency_table.T

# Perform the chi-squared test
chi2, p, _, _ = chi2_contingency(contingency_table)

# Print the results
print(f"Chi-squared value: {chi2}")
print(f"P-value: {p}")

# Interpret the results
if p < 0.05:
    print("The distributions are significantly different.")
else:
    print("There is no significant difference between the distributions.")
# Out:
# Chi-squared value: 90.43253043253044
# P-value: 5.450763070171291e-18
# The distributions are significantly different.
